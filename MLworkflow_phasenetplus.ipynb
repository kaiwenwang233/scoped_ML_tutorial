# %% [markdown]
# # SCOPED Container for ML-DD earthquake catalog computation
# This notebook is part of the SCOPED container for machine learning based earthquake catalog computation. It uses one day of continous waveforms during the 2016-2017 central Italy earthquake sequence as demo. The SCOPED Container page is at https://github.com/SeisSCOPED/ml_catalog
#
# Follow the instructions to pull and run the tutorial container:
#
# ## To run it on your local machine:
# Install docker from https://docs.docker.com/get-docker/
#
# For Mac: ```https://docs.docker.com/desktop/install/mac-install/```
#
# For Linux: ```https://docs.docker.com/desktop/install/linux-install/```
#
# For Windows: ```https://docs.docker.com/desktop/install/windows-install/```
#
# ## To run it on AWS cloud (SCOPED workshop users):
# Follow instructions on https://seisscoped.org/HPS-book/chapters/cloud/AWS_101.html to log in to AWS and launching your instance.
#
# When launching your instance (at Step 2), in the **Application and OS Images (Amazon Machine Image)** block, choose **Architecture* as **64-bit (Arm)**.
#
# Use 'option 1' to install docker on your instance with the following command:
# ```
# sudo yum install docker -y
# sudo service docker start
# sudo usermod -a -G docker ec2-user
# docker --version
# ```
#
# And then pull container image with the command lines below.
#
# ## Pulling container image
# Use the following commands to pull the container locally from the GitHub Container Registry (GHCR):
# ```
# docker pull ghcr.io/seisscoped/ml_catalog:ubuntu22.04_jupyterlab
#
# docker run -p 8888:8888 ghcr.io/seisscoped/ml_catalog:ubuntu22.04_jupyterlab
# ```
# ##### For **SCOPED workshop users** running on AWS cloud, use:
# ```
# sudo docker pull ghcr.io/seisscoped/ml_catalog:latest
#
# sudo docker run -p 8888:8888 ghcr.io/seisscoped/ml_catalog:latest
# ```
#
# ### Run tutorial Jupyter Notebook
#
# The container will start JupyterLab with a link to open it in a web browser, something like:
# ```
# To access the notebook, open this file in a browser:
#         file:///root/.local/share/jupyter/runtime/nbserver-1-open.html
# Or copy and paste one of these URLs:
#         http://35e1877ea874:8888/?token=1cfd3a35f9d58cfd52807494ab36dd7166140bb856dbfbb7
# or http://127.0.0.1:8888/?token=1cfd3a35f9d58cfd52807494ab36dd7166140bb856dbfbb7
#
# ```
# Copy and paste one of the URLs to open it in a browser. Then run the tutorial notebook ```MLworkflow_phasenetplus.ipynb```
#
# ##### For **SCOPED workshop users**,
#
# Find the **Public IPv4 DNS** of your AWS instance, replace the IP address in the link with this Public IPv4 DNS and open it in your web browser.
#
# This will open a JupyterLab of the tutorial. Then run the notebook "MLworkflow_phasenetplus.ipynb" for machine learning catalog computation workflow.
#
# ### To download results
#
# ##### Copy file from container
# ```docker cp <your container id>:<path in container> <path on cloud>```
#
# example:
#
# ```docker cp 91a27915d3f2:/app/hypodd/results_hypodd/hypoDD.reloc .```
#
# ##### Copy file from AWS
# ```scp -r -i "<your key pair file>" ec2-user@<Public IPv4 DNS>:<path on cloud> <your local path>```
#
# example:
#
# ```scp -r -i "mykey.pem" ec2-user@ec2-44-234-85-195.us-west-2.compute.amazonaws.com:/home/ec2-user/hypoDD.reloc ./fromAWScontainer/.```

# %% [markdown]
# # SCOPED tutorial for ML-DD earthquake catalog computation
#
# This is a Jupyther Notebook of SCOPED tutorial for machine learning catalog construction workflow.
#
# The notebook includes code and examples to download continuous data, detect and pick phases with PhaseNet, assoicate the phases with GaMMA, locate them with HypoInverse, and relocate the events with HypoDD.
#
# ### Links to the packages/functions:
#
# - Data downloaded with ObsPy Mass Downloader fuction (https://docs.obspy.org/packages/obspy.clients.fdsn.html)
#
# - PhaseNet for phase picking (https://github.com/AI4EPS/PhaseNet)
#
# - PhaseNet+ for picking arrival time and polarity (https://github.com/AI4EPS/EQNet?tab=readme-ov-file#phasenet-1)
#
# - GaMMA for picks association (https://github.com/AI4EPS/GaMMA)
#
# - HypoInverse for single event location (https://www.usgs.gov/software/hypoinverse-earthquake-location)
#
# - HypoDD for double difference relocation (https://github.com/fwaldhauser/HypoDD)
#
# - XTime for cross-correlation delay time measurement
#
# ### References:
#
# - Moritz Beyreuther, Robert Barsch, Lion Krischer, Tobias Megies, Yannik Behr and Joachim Wassermann (2010), ObsPy: A Python Toolbox for Seismology, SRL, 81(3), 530-533, doi:10.1785/gssrl.81.3.530.
#
# - Zhu, Weiqiang, and Gregory C. Beroza. "PhaseNet: A Deep-Neural-Network-Based Seismic Arrival Time Picking Method." arXiv preprint arXiv:1803.03211 (2018).
#
# - Zhu, Weiqiang et al. "Earthquake Phase Association using a Bayesian Gaussian Mixture Model." (2021)
#
# - Klein, Fred W. User's guide to HYPOINVERSE-2000, a Fortran program to solve for earthquake locations and magnitudes. No. 2002-171. US Geological Survey, 2002.
#
# - Waldhauser, Felix, and William L. Ellsworth, A double-difference
# earthquake location algorithm: Method and application to the northern
# Hayward fault, California, Bull. Seism. Soc. Am. 90, 1353-1368, 2000.
#
# - Schaff, David P., et al. "Optimizing correlation techniques for improved earthquake location." Bulletin of the Seismological Society of America 94.2 (2004): 705-721.
#
# - Tan, Y. J., F. Waldhauser, W. L. Ellsworth, M. Zhang, W. Zhu, M. Michele, L. Chiaraluce, G. C. Beroza, M. Segou (2021). Machine‐Learning‐Based High‐Resolution Earthquake Catalog Reveals How Complex Fault Structures Were Activated during the 2016–2017 Central Italy Sequence, The Seismic Record, 1 (1): 11–19.

# %% [markdown]
# ### ML catalog tutorial: Amatrice, Italy October 2016
#
# Tutorial Steps:
# 1. Download data
# 2. Phasenet detection & phase picking
# 3. GaMMA Association
# 4. HypoInverse location
# 5. HypoDD double difference relocation
#
# The parameters are set for this demo dataset. If you are applying it to other dataset, you might need to change <mark>parameters in highlighted lines</mark> base on your dataset.

# %% [markdown]
# ### Download data
# Download continous data from IRIS. Here we download one-day data for test run.
#
# Data downloaded with ObsPy Mass Downloader fuction.
# See more information at https://docs.obspy.org/packages/obspy.clients.fdsn.html
#
# <mark>Data download parameters: </mark>
#
# - Define study region: latitude, longitude, maxradius
# - Time range: starttime, endtime
# - Station information: network, channel_priorities

# %%
import obspy
from obspy.clients.fdsn import Client
from obspy import UTCDateTime
from obspy.clients.fdsn.mass_downloader import RectangularDomain, \
    Restrictions, MassDownloader, CircularDomain
from pathlib import Path

domain = CircularDomain(latitude=42.75, longitude=13.25,
                                minradius=0.0, maxradius=1)

wfBaseDir='./waveforms'
Path(wfBaseDir).mkdir(parents=True, exist_ok=True)

restrictions = Restrictions(
    starttime = obspy.UTCDateTime(2016, 10,18,0,0,0),
    endtime   = obspy.UTCDateTime(2016, 10,19,0,0,0),
    chunklength_in_sec=86400,
    network="YR",
    channel_priorities=["[HE][HN]?"],
    reject_channels_with_gaps=False,
    minimum_length=0.0,
    minimum_interstation_distance_in_m=100.0)

mdl = MassDownloader(providers=["IRIS"])
mdl.download(domain, restrictions,
             mseed_storage=wfBaseDir+"/{network}/{station}/"
                         "{channel}.{location}.{starttime}.{endtime}.mseed",
             stationxml_storage="stations")
# Out:
# [2024-05-23 14:26:15,726] - obspy.clients.fdsn.mass_downloader - INFO: Initializing FDSN client(s) for IRIS.
# [2024-05-23 14:26:15,929] - obspy.clients.fdsn.mass_downloader - INFO: Successfully initialized 1 client(s): IRIS.
# [2024-05-23 14:26:15,930] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 0
# [2024-05-23 14:26:15,931] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Requesting reliable availability.
# [2024-05-23 14:26:16,121] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully requested availability (0.19 seconds)
# [2024-05-23 14:26:16,127] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Found 24 stations (72 channels).
# [2024-05-23 14:26:16,137] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Will attempt to download data from 24 stations.
# [2024-05-23 14:26:16,142] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Status for 72 time intervals/channels before downloading: NEEDS_DOWNLOADING
# [2024-05-23 14:26:21,735] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:26:22,730] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:26:25,119] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:26:28,926] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:26:29,808] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:26:33,197] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:26:35,177] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:26:36,521] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:26:40,222] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:26:41,589] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:26:45,002] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:26:45,690] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:26:50,031] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:26:50,189] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:26:55,016] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:26:55,578] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:26:56,550] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:27:02,167] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:27:04,247] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:27:04,556] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:27:06,825] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:27:11,227] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:27:11,331] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:27:12,616] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:27:17,734] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:27:19,431] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:27:19,658] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:27:25,036] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:27:29,093] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:27:29,211] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:27:29,718] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:27:34,405] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:27:35,233] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:27:36,707] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:27:39,668] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:27:39,970] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:27:43,690] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:27:44,357] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:27:45,746] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:27:49,400] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:27:49,848] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:27:52,194] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:27:55,993] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:27:57,149] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:28:00,605] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:28:01,199] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:28:04,241] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:28:06,240] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:28:08,862] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:28:09,604] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:28:11,265] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:28:14,801] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:28:16,067] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:28:17,752] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:28:20,742] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:28:21,729] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:28:25,774] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:28:26,914] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:28:27,433] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:28:33,525] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:28:33,566] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:28:35,716] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:28:38,232] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:28:38,659] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:28:42,794] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:28:44,447] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:28:45,437] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:28:50,153] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:28:51,681] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:28:55,728] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:29:00,227] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:29:07,662] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 1 channels (of 1)
# [2024-05-23 14:29:07,663] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Launching basic QC checks...
# [2024-05-23 14:29:08,032] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Downloaded 850.8 MB [5079.23 KB/sec] of data, 0.0 MB of which were discarded afterwards.
# [2024-05-23 14:29:08,033] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Status for 72 time intervals/channels after downloading: DOWNLOADED
# [2024-05-23 14:29:08,087] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 'stations/YR.ED01.xml'.
# [2024-05-23 14:29:08,094] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 'stations/YR.ED05.xml'.
# [2024-05-23 14:29:08,096] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 'stations/YR.ED03.xml'.
# [2024-05-23 14:29:08,147] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 'stations/YR.ED02.xml'.
# [2024-05-23 14:29:08,149] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 'stations/YR.ED04.xml'.
# [2024-05-23 14:29:08,151] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 'stations/YR.ED06.xml'.
# [2024-05-23 14:29:08,199] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 'stations/YR.ED07.xml'.
# [2024-05-23 14:29:08,201] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 'stations/YR.ED09.xml'.
# [2024-05-23 14:29:08,209] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 'stations/YR.ED11.xml'.
# [2024-05-23 14:29:08,255] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 'stations/YR.ED10.xml'.
# [2024-05-23 14:29:08,255] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 'stations/YR.ED08.xml'.
# [2024-05-23 14:29:08,273] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 'stations/YR.ED12.xml'.
# [2024-05-23 14:29:08,305] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 'stations/YR.ED14.xml'.
# [2024-05-23 14:29:08,307] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 'stations/YR.ED16.xml'.
# [2024-05-23 14:29:08,321] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 'stations/YR.ED18.xml'.
# [2024-05-23 14:29:08,358] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 'stations/YR.ED15.xml'.
# [2024-05-23 14:29:08,372] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 'stations/YR.ED17.xml'.
# [2024-05-23 14:29:08,377] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 'stations/YR.ED19.xml'.
# [2024-05-23 14:29:08,421] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 'stations/YR.ED20.xml'.
# [2024-05-23 14:29:08,435] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 'stations/YR.ED22.xml'.
# [2024-05-23 14:29:08,439] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 'stations/YR.ED24.xml'.
# [2024-05-23 14:29:08,468] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 'stations/YR.ED21.xml'.
# [2024-05-23 14:29:08,487] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 'stations/YR.ED25.xml'.
# [2024-05-23 14:29:08,493] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 'stations/YR.ED23.xml'.
# [2024-05-23 14:29:08,619] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Downloaded 24 station files [6.2 MB] in 0.5 seconds [13919.54 KB/sec].
# [2024-05-23 14:29:08,621] - obspy.clients.fdsn.mass_downloader - INFO: ============================== Final report
# [2024-05-23 14:29:08,621] - obspy.clients.fdsn.mass_downloader - INFO: 0 MiniSEED files [0.0 MB] already existed.
# [2024-05-23 14:29:08,622] - obspy.clients.fdsn.mass_downloader - INFO: 0 StationXML files [0.0 MB] already existed.
# [2024-05-23 14:29:08,624] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Acquired 72 MiniSEED files [850.8 MB].
# [2024-05-23 14:29:08,624] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Acquired 24 StationXML files [6.2 MB].
# [2024-05-23 14:29:08,624] - obspy.clients.fdsn.mass_downloader - INFO: Downloaded 857.0 MB in total.
# {'IRIS': <obspy.clients.fdsn.mass_downloader.download_helpers.ClientDownloadHelper at 0xffff0c98a2f0>}

# %% [markdown]
# ### Prepare PhaseNet input files and running PhaseNet for phase picking
# PhaseNet model from https://github.com/AI4EPS/PhaseNet
#
# ##### Reference:
# Zhu, Weiqiang, and Gregory C. Beroza. "PhaseNet: A Deep-Neural-Network-Based Seismic Arrival Time Picking Method." arXiv preprint arXiv:1803.03211 (2018).
#
# ##### Write input waveform file path from the downloaded miniseed waveforms:
# write input files required by PhaseNet: use the miniseed data we just downloaded

# %%
import glob
import numpy as np
from pathlib import Path
from obspy import read

wfBaseDir='./waveforms'
PhasenetResultDir='./results_phasenet_plus'
Path(PhasenetResultDir).mkdir(parents=True, exist_ok=True)

for fname in glob.glob(wfBaseDir+'/*/*/*Z..*.mseed'):
    stream = read(fname.replace('Z..', '?..'))
    Path('./waveforms_combined/'+fname.split('/')[-3]+'/'+fname.split('/')[-2]).mkdir(parents=True, exist_ok=True)
    out_fname = fname.replace('Z..', '..').replace('waveforms', 'waveforms_combined')
    stream.write(out_fname, 'MSEED')

mseed_path='./waveforms_combined/*/*/*.mseed'
filenames = glob.glob(mseed_path)
filenames=np.unique(filenames)
print('number of stations',len(filenames))


np.savetxt(PhasenetResultDir+'/mseed.txt', filenames, fmt='%s')
# Out:
# number of stations 24

# %% [markdown]
# ##### Write station file from the .xml files:
# generate input station file with the .xml files we just downloaded

# %%
from obspy import read_inventory
from collections import defaultdict
import pandas as pd
inv = read_inventory("./stations/*.xml")

station_locs = defaultdict(dict)
stations=inv
for network in stations:
    for station in network:
        for chn in station:
            sid = f"{network.code}.{station.code}.{chn.location_code}.{chn.code[:-1]}"
            if sid in station_locs:
                station_locs[sid]["component"] += f",{chn.code[-1]}"
                station_locs[sid]["response"] += f",{chn.response.instrument_sensitivity.value:.2f}"
            else:
                component = f"{chn.code[-1]}"
                response = f"{chn.response.instrument_sensitivity.value:.2f}"
                dtype = chn.response.instrument_sensitivity.input_units.lower()
                tmp_dict = {}
                tmp_dict["longitude"], tmp_dict["latitude"], tmp_dict["elevation(m)"] = (
                    chn.longitude,
                    chn.latitude,
                    chn.elevation,
                )
                tmp_dict["component"], tmp_dict["response"], tmp_dict["unit"] = component, response, dtype
                station_locs[sid] = tmp_dict
            if station_locs[sid]["component"]=='Z':
                station_locs[sid]["response"]= f"0,0,"+station_locs[sid]["response"]
            elif station_locs[sid]["component"]=='N,Z':
                station_locs[sid]["response"]= f"0,"+station_locs[sid]["response"]
station_locs = pd.DataFrame.from_dict(station_locs, orient='index')
station_locs["id"] = station_locs.index
station_locs = station_locs.rename_axis('station').reset_index()
station_locs.to_csv("./stations.csv",sep='\t')
station_locs
# Out:
#         station  longitude   latitude  elevation(m) component  \
# 0   YR.ED01..HH  13.092880  42.526360         739.0     E,N,Z
# 1   YR.ED02..HH  12.928840  42.603512         831.0     E,N,Z
# 2   YR.ED03..HH  13.190310  42.602959        1053.0     E,N,Z
# 3   YR.ED04..HH  13.297170  42.574291        1303.0     E,N,Z
# 4   YR.ED05..HH  13.364860  42.483490        1187.0     E,N,Z
# 5   YR.ED06..HH  13.227740  42.464062         925.0     E,N,Z
# 6   YR.ED07..HH  13.465010  42.628208        1025.0     E,N,Z
# 7   YR.ED08..HH  13.054200  42.458881        1016.0     E,N,Z
# 8   YR.ED09..HH  13.423670  42.800129         466.0     E,N,Z
# 9   YR.ED10..HH  13.141180  42.777069         822.0     E,N,Z
# 10  YR.ED11..HH  13.033480  42.688438         975.0     E,N,Z
# 11  YR.ED12..HH  12.977230  42.806370        1127.0     E,N,Z
# 12  YR.ED14..HH  13.433130  42.444881        1230.0     E,N,Z
# 13  YR.ED15..HH  13.558160  42.527802        1012.0     E,N,Z
# 14  YR.ED16..HH  13.307080  42.837109        1039.0     E,N,Z
# 15  YR.ED17..HH  13.308550  42.965851         815.0     E,N,Z
# 16  YR.ED18..HH  13.243250  42.991459        1355.0     E,N,Z
# 17  YR.ED19..HH  13.139160  42.919621        1223.0     E,N,Z
# 18  YR.ED20..HH  13.435305  42.748829         892.0     E,N,Z
# 19  YR.ED21..HH  13.272270  43.030071         720.0     E,N,Z
# 20  YR.ED22..HH  13.325200  43.006748         620.0     E,N,Z
# 21  YR.ED23..HH  13.287100  42.743191        1045.0     E,N,Z
# 22  YR.ED24..HH  13.192320  42.655640        1104.0     E,N,Z
# 23  YR.ED25..HH  13.351880  42.598770        1353.0     E,N,Z
#
#                                      response unit           id
# 0   2452670000.00,2458380000.00,2452670000.00  m/s  YR.ED01..HH
# 1   2396900000.00,2408160000.00,2385590000.00  m/s  YR.ED02..HH
# 2   2503140000.00,2533330000.00,2502610000.00  m/s  YR.ED03..HH
# 3   2478170000.00,2468390000.00,2486490000.00  m/s  YR.ED04..HH
# 4   2332040000.00,2334620000.00,2323640000.00  m/s  YR.ED05..HH
# 5   2484410000.00,2478170000.00,2481830000.00  m/s  YR.ED06..HH
# 6   2326530000.00,2325220000.00,2309940000.00  m/s  YR.ED07..HH
# 7   2259960000.00,2259720000.00,2246210000.00  m/s  YR.ED08..HH
# 8   2413370000.00,2432210000.00,2406500000.00  m/s  YR.ED09..HH
# 9   2497920000.00,2502080000.00,2497400000.00  m/s  YR.ED10..HH
# 10  2414130000.00,2436440000.00,2448420000.00  m/s  YR.ED11..HH
# 11  2364530000.00,2334970000.00,2364890000.00  m/s  YR.ED12..HH
# 12  2391130000.00,2414980000.00,2441960000.00  m/s  YR.ED14..HH
# 13  2484340000.00,2496340000.00,2543360000.00  m/s  YR.ED15..HH
# 14  2512550000.00,2500000000.00,2468880000.00  m/s  YR.ED16..HH
# 15  1976650000.00,1988300000.00,1953450000.00  m/s  YR.ED17..HH
# 16  2469240000.00,2493720000.00,2493780000.00  m/s  YR.ED18..HH
# 17  2491160000.00,2487450000.00,2497390000.00  m/s  YR.ED19..HH
# 18  2195610000.00,2185790000.00,2189260000.00  m/s  YR.ED20..HH
# 19  2463140000.00,2456910000.00,2455960000.00  m/s  YR.ED21..HH
# 20  2417850000.00,2419350000.00,2423940000.00  m/s  YR.ED22..HH
# 21  2318760000.00,2340510000.00,2317430000.00  m/s  YR.ED23..HH
# 22  2488010000.00,2543750000.00,2506750000.00  m/s  YR.ED24..HH
# 23  2452670000.00,2452210000.00,2448100000.00  m/s  YR.ED25..HH

# %% [markdown]
# ### Run PhaseNet
# Phase picking on continous data. Output phase picks for given station and waveform files.

# %%
# %cd /app/
# !python ./EQNet/predict.py --model phasenet_plus --add_polarity --data_list ./results_phasenet_plus/mseed.txt --result_path ./results_phasenet_plus --batch_size=1 --format mseed --device=cpu --subdir_level 2 --min_prob 0.1
# Out:
# /app
# Not using distributed mode
# Namespace(model='phasenet_plus', resume='', backbone='unet', phases=['P', 'S'], device='cpu', workers=0, batch_size=1, use_deterministic_algorithms=False, amp=False, world_size=1, dist_url='env://', data_path='./', data_list='./results_phasenet_plus/mseed.txt', hdf5_file=None, prefix='', format='mseed', dataset='das', result_path='./results_phasenet_plus', plot_figure=False, min_prob=0.1, add_polarity=True, add_event=False, sampling_rate=100.0, highpass_filter=None, response_path=None, response_xml=None, subdir_level=2, cut_patch=False, nt=20480, nx=5120, resample_time=False, resample_space=False, system=None, location=None, skip_existing=False, distributed=False)
# Total samples:  ./.mseed : 24 files
# Downloading: "https://github.com/AI4EPS/models/releases/download/PhaseNet-Plus-v1/model_99.pth" to ./model_phasenet_plus/model_99.pth
# 100%|███████████████████████████████████████| 17.9M/17.9M [00:00<00:00, 239MB/s]
# Predicting: 100%|███████████████████████████████| 24/24 [08:44<00:00, 21.85s/it]
# Merging picks_phasenet_plus: 24it [00:00, 177.85it/s]
# Number of picks: 58427
# Number of P picks: 28915
# Number of S picks: 29512
# Merging events_phasenet_plus: 24it [00:00, 286.03it/s]
# Number of event x station: 30680

# %% [markdown]
# ### Run GaMMA
# Associating PhaseNet picks into events with GaMMA (https://github.com/AI4EPS/GaMMA)
#
# ##### Reference:
# Zhu, Weiqiang et al. "Earthquake Phase Association using a Bayesian Gaussian Mixture Model." (2021)
#
# ##### Set GaMMA parameters:
# <mark>Parameters you might want to change based on your dataset: </mark>
#
# - Define study region: center=(latitude, longitude), horizontal_degree, vertical_degree, z(km)
# - Time range: starttime, endtime
# - Station information: network_list, channel_list
# - Association parameters:
#     - dbscan_eps (for sparse network use a larger number)
#     - min_picks_per_eq (minimum number of associated picks per event)
#     - max_sigma11 (a larger value allows larger pick uncertainty)

# %%
GMMAResultDir='./GMMA'
Path(GMMAResultDir).mkdir(parents=True, exist_ok=True)

catalog_csv = GMMAResultDir+"/catalog_gamma.csv"
picks_csv = GMMAResultDir+"/picks_gamma.csv"


region_name = "Italy"
center = (13.2, 42.7)
horizontal_degree = 0.85
vertical_degree = 0.85
starttime = obspy.UTCDateTime("2016-10-18T00")
endtime =   obspy.UTCDateTime("2016-10-19T00")
network_list = ["IV","YR"]
channel_list = "HH*,EH*,HN*,EN*"

config = {}
config["region"] = region_name
config["center"] = center
config["xlim_degree"] = [center[0] - horizontal_degree / 2, center[0] + horizontal_degree / 2]
config["ylim_degree"] = [center[1] - vertical_degree / 2, center[1] + vertical_degree / 2]
config["starttime"] = starttime.datetime.isoformat()
config["endtime"] = endtime.datetime.isoformat()
config["networks"] = network_list
config["channels"] = channel_list
config["degree2km"] = 111
config["degree2km_x"] = 82
config['vel']= {"p":6.2, "s":3.3}


config["dims"] = ['x(km)', 'y(km)', 'z(km)']
config["use_dbscan"] = True
config["use_amplitude"] = True
config["x(km)"] = (np.array(config["xlim_degree"])-np.array(config["center"][0]))*config["degree2km_x"]
config["y(km)"] = (np.array(config["ylim_degree"])-np.array(config["center"][1]))*config["degree2km"]
config["z(km)"] = (0, 20)

# DBSCAN
config["bfgs_bounds"] = ((config["x(km)"][0]-1, config["x(km)"][1]+1), #x
                        (config["y(km)"][0]-1, config["y(km)"][1]+1), #y
                        (0, config["z(km)"][1]+1), #x
                        (None, None)) #t
config["dbscan_eps"] = 6
config["dbscan_min_samples"] = min(len(stations), 3)
config["min_picks_per_eq"] = min(len(stations)//2+1, 10)

config["method"] = "BGMM"
if config["method"] == "BGMM":
    config["oversample_factor"] = 4
if config["method"] == "GMM":
    config["oversample_factor"] = 1

config["max_sigma11"] = 2.0
config["max_sigma22"] = 1.0
config["max_sigma12"] = 1.0

config["use_amplitude"] = False
for k, v in config.items():
    print(f"{k}: {v}")
# Out:
# region: Italy
# center: (13.2, 42.7)
# xlim_degree: [12.774999999999999, 13.625]
# ylim_degree: [42.275000000000006, 43.125]
# starttime: 2016-10-18T00:00:00
# endtime: 2016-10-19T00:00:00
# networks: ['IV', 'YR']
# channels: HH*,EH*,HN*,EN*
# degree2km: 111
# degree2km_x: 82
# vel: {'p': 6.2, 's': 3.3}
# dims: ['x(km)', 'y(km)', 'z(km)']
# use_dbscan: True
# use_amplitude: False
# x(km): [-34.85  34.85]
# y(km): [-47.175  47.175]
# z(km): (0, 20)
# bfgs_bounds: ((-35.85000000000006, 35.85000000000006), (-48.174999999999685, 48.174999999999685), (0, 21), (None, None))
# dbscan_eps: 6
# dbscan_min_samples: 3
# min_picks_per_eq: 10
# method: BGMM
# oversample_factor: 4
# max_sigma11: 2.0
# max_sigma22: 1.0
# max_sigma12: 1.0

# %% [markdown]
# ##### Write station file for GaMMA:
# Read station file and write in GaMMA input format.

# %%
station_path='./stations.csv'
stations = pd.read_csv(station_path, delimiter="\t", index_col=0)

stations["x(km)"] = stations["longitude"].apply(lambda x: (x - config["center"][0])*config["degree2km_x"])
stations["y(km)"] = stations["latitude"].apply(lambda x: (x - config["center"][1])*config["degree2km"])
stations["z(km)"] = stations["elevation(m)"].apply(lambda x: -x/1e3)
stations["id"] = stations["id"].apply(lambda x: x.split('.')[1])
stations=stations.drop_duplicates(subset=['id'], keep='first')
stations['elevation(m)']=stations['elevation(m)']-np.min(stations['elevation(m)'])
stations['z(km)']=stations['z(km)']-np.min(stations['z(km)'])

stations
# Out:
#         station  longitude   latitude  elevation(m) component  \
# 0   YR.ED01..HH  13.092880  42.526360         273.0     E,N,Z
# 1   YR.ED02..HH  12.928840  42.603512         365.0     E,N,Z
# 2   YR.ED03..HH  13.190310  42.602959         587.0     E,N,Z
# 3   YR.ED04..HH  13.297170  42.574291         837.0     E,N,Z
# 4   YR.ED05..HH  13.364860  42.483490         721.0     E,N,Z
# 5   YR.ED06..HH  13.227740  42.464062         459.0     E,N,Z
# 6   YR.ED07..HH  13.465010  42.628208         559.0     E,N,Z
# 7   YR.ED08..HH  13.054200  42.458881         550.0     E,N,Z
# 8   YR.ED09..HH  13.423670  42.800129           0.0     E,N,Z
# 9   YR.ED10..HH  13.141180  42.777069         356.0     E,N,Z
# 10  YR.ED11..HH  13.033480  42.688438         509.0     E,N,Z
# 11  YR.ED12..HH  12.977230  42.806370         661.0     E,N,Z
# 12  YR.ED14..HH  13.433130  42.444881         764.0     E,N,Z
# 13  YR.ED15..HH  13.558160  42.527802         546.0     E,N,Z
# 14  YR.ED16..HH  13.307080  42.837109         573.0     E,N,Z
# 15  YR.ED17..HH  13.308550  42.965851         349.0     E,N,Z
# 16  YR.ED18..HH  13.243250  42.991459         889.0     E,N,Z
# 17  YR.ED19..HH  13.139160  42.919621         757.0     E,N,Z
# 18  YR.ED20..HH  13.435305  42.748829         426.0     E,N,Z
# 19  YR.ED21..HH  13.272270  43.030071         254.0     E,N,Z
# 20  YR.ED22..HH  13.325200  43.006748         154.0     E,N,Z
# 21  YR.ED23..HH  13.287100  42.743191         579.0     E,N,Z
# 22  YR.ED24..HH  13.192320  42.655640         638.0     E,N,Z
# 23  YR.ED25..HH  13.351880  42.598770         887.0     E,N,Z
#
#                                      response unit    id     x(km)      y(km)  \
# 0   2452670000.00,2458380000.00,2452670000.00  m/s  ED01  -8.78384 -19.274040
# 1   2396900000.00,2408160000.00,2385590000.00  m/s  ED02 -22.23512 -10.710168
# 2   2503140000.00,2533330000.00,2502610000.00  m/s  ED03  -0.79458 -10.771551
# 3   2478170000.00,2468390000.00,2486490000.00  m/s  ED04   7.96794 -13.953699
# 4   2332040000.00,2334620000.00,2323640000.00  m/s  ED05  13.51852 -24.032610
# 5   2484410000.00,2478170000.00,2481830000.00  m/s  ED06   2.27468 -26.189118
# 6   2326530000.00,2325220000.00,2309940000.00  m/s  ED07  21.73082  -7.968912
# 7   2259960000.00,2259720000.00,2246210000.00  m/s  ED08 -11.95560 -26.764209
# 8   2413370000.00,2432210000.00,2406500000.00  m/s  ED09  18.34094  11.114319
# 9   2497920000.00,2502080000.00,2497400000.00  m/s  ED10  -4.82324   8.554659
# 10  2414130000.00,2436440000.00,2448420000.00  m/s  ED11 -13.65464  -1.283382
# 11  2364530000.00,2334970000.00,2364890000.00  m/s  ED12 -18.26714  11.807070
# 12  2391130000.00,2414980000.00,2441960000.00  m/s  ED14  19.11666 -28.318209
# 13  2484340000.00,2496340000.00,2543360000.00  m/s  ED15  29.36912 -19.113978
# 14  2512550000.00,2500000000.00,2468880000.00  m/s  ED16   8.78056  15.219099
# 15  1976650000.00,1988300000.00,1953450000.00  m/s  ED17   8.90110  29.509461
# 16  2469240000.00,2493720000.00,2493780000.00  m/s  ED18   3.54650  32.351949
# 17  2491160000.00,2487450000.00,2497390000.00  m/s  ED19  -4.98888  24.377931
# 18  2195610000.00,2185790000.00,2189260000.00  m/s  ED20  19.29501   5.420019
# 19  2463140000.00,2456910000.00,2455960000.00  m/s  ED21   5.92614  36.637881
# 20  2417850000.00,2419350000.00,2423940000.00  m/s  ED22  10.26640  34.049028
# 21  2318760000.00,2340510000.00,2317430000.00  m/s  ED23   7.14220   4.794201
# 22  2488010000.00,2543750000.00,2506750000.00  m/s  ED24  -0.62976  -4.923960
# 23  2452670000.00,2452210000.00,2448100000.00  m/s  ED25  12.45416 -11.236530
#
#     z(km)
# 0   0.616
# 1   0.524
# 2   0.302
# 3   0.052
# 4   0.168
# 5   0.430
# 6   0.330
# 7   0.339
# 8   0.889
# 9   0.533
# 10  0.380
# 11  0.228
# 12  0.125
# 13  0.343
# 14  0.316
# 15  0.540
# 16  0.000
# 17  0.132
# 18  0.463
# 19  0.635
# 20  0.735
# 21  0.310
# 22  0.251
# 23  0.002

# %% [markdown]
# ##### Load pick file from PhaseNet output:
# Read picks from PhaseNet output and remove duplicated picks (<0.05s).

# %%
picks_path='./results_phasenet_plus/picks_phasenet_plus.csv'
picks = pd.read_csv(picks_path,delimiter=",")

picks["time_idx"] = picks["phase_time"].apply(lambda x: UTCDateTime(x).strftime("%Y-%m-%dT%H")) # process by hours
picks["timestamp"]=picks["phase_time"].apply(lambda x: UTCDateTime(x).datetime)
picks["id"] = picks["station_id"].apply(lambda x: x.split('.')[1])
picks['type']=picks['phase_type'].str.lower()
picks["prob"]=picks['phase_score']
picks['amp']=picks['phase_amplitude']

picks
# Out:
#         station_id  phase_index               phase_time  phase_score  \
# 0      YR.ED17..HH          374  2016-10-18T00:00:03.740        0.279
# 1      YR.ED17..HH          545  2016-10-18T00:00:05.450        0.475
# 2      YR.ED17..HH         1470  2016-10-18T00:00:14.700        0.880
# 3      YR.ED18..HH         1506  2016-10-18T00:00:15.060        0.109
# 4      YR.ED17..HH         1645  2016-10-18T00:00:16.450        0.813
# ...            ...          ...                      ...          ...
# 58422  YR.ED25..HH      8638311  2016-10-18T23:59:43.110        0.150
# 58423  YR.ED17..HH      8639078  2016-10-18T23:59:50.780        0.561
# 58424  YR.ED17..HH      8639303  2016-10-18T23:59:53.030        0.488
# 58425  YR.ED10..HH      8639467  2016-10-18T23:59:54.670        0.910
# 58426  YR.ED10..HH      8639516  2016-10-18T23:59:55.160        0.909
#
#       phase_type  dt_s  phase_polarity  phase_amplitude       time_idx  \
# 0              P  0.01          -0.181            296.2  2016-10-18T00
# 1              S  0.01          -0.017            385.7  2016-10-18T00
# 2              P  0.01           0.414            549.1  2016-10-18T00
# 3              P  0.01           0.080            739.4  2016-10-18T00
# 4              S  0.01          -0.056           1163.0  2016-10-18T00
# ...          ...   ...             ...              ...            ...
# 58422          S  0.01           0.050            614.7  2016-10-18T23
# 58423          P  0.01           0.281            496.4  2016-10-18T23
# 58424          S  0.01          -0.020            561.3  2016-10-18T23
# 58425          P  0.01          -0.565           3479.0  2016-10-18T23
# 58426          S  0.01          -0.014           3479.0  2016-10-18T23
#
#                     timestamp    id type   prob     amp
# 0     2016-10-18 00:00:03.740  ED17    p  0.279   296.2
# 1     2016-10-18 00:00:05.450  ED17    s  0.475   385.7
# 2     2016-10-18 00:00:14.700  ED17    p  0.880   549.1
# 3     2016-10-18 00:00:15.060  ED18    p  0.109   739.4
# 4     2016-10-18 00:00:16.450  ED17    s  0.813  1163.0
# ...                       ...   ...  ...    ...     ...
# 58422 2016-10-18 23:59:43.110  ED25    s  0.150   614.7
# 58423 2016-10-18 23:59:50.780  ED17    p  0.561   496.4
# 58424 2016-10-18 23:59:53.030  ED17    s  0.488   561.3
# 58425 2016-10-18 23:59:54.670  ED10    p  0.910  3479.0
# 58426 2016-10-18 23:59:55.160  ED10    s  0.909  3479.0
#
# [58427 rows x 14 columns]

# %% [markdown]
# ##### Run GaMMA association:
# Associate the picks into events and write results (a catalog with associated picks).

# %%
from gamma import BayesianGaussianMixture, GaussianMixture
from gamma.utils import convert_picks_csv, association, from_seconds
from tqdm import tqdm

pbar = tqdm(sorted(list(set(picks["time_idx"]))))
event_idx0 = 0 ## current earthquake index
assignments = []
if (len(picks) > 0) and (len(picks) < 5000):
    catalogs, assignments = association(picks, stations, config, event_idx0, config["method"], pbar=pbar)
    event_idx0 += len(catalogs)
else:
    catalogs = []
    for i, hour in enumerate(pbar):
        picks_ = picks[picks["time_idx"] == hour]
        if len(picks_) == 0:
            continue
        catalog, assign = association(picks_, stations, config, event_idx0, config["method"], pbar=pbar)
        event_idx0 += len(catalog)
        catalogs.extend(catalog)
        assignments.extend(assign)

## create catalog
catalogs = pd.DataFrame(catalogs)
catalogs["longitude"] = catalogs["x(km)"].apply(lambda x: x/config["degree2km_x"] + config["center"][0])
catalogs["latitude"] = catalogs["y(km)"].apply(lambda x: x/config["degree2km"] + config["center"][1])
catalogs["depth_km"] = catalogs["z(km)"]
with open(catalog_csv, 'w') as fp:
    catalogs.to_csv(fp, sep="\t", index=False,
                    float_format="%.3f",
                    date_format='%Y-%m-%dT%H:%M:%S.%f',
                    columns=["time", "magnitude", "longitude", "latitude", "depth_km", "sigma_time", "sigma_amp", "cov_time_amp", "event_index", "gamma_score"])
catalogs = catalogs[['time', 'magnitude', 'longitude', 'latitude', 'depth_km', 'sigma_time', 'sigma_amp', 'gamma_score']]

## add assignment to picks
assignments = pd.DataFrame(assignments, columns=["pick_idx", "event_index", "gamma_score"])
picks = picks.join(assignments.set_index("pick_idx")).fillna(-1).astype({'event_index': int})
with open(picks_csv, 'w') as fp:
    picks.to_csv(fp, sep="\t", index=False,
                    date_format='%Y-%m-%dT%H:%M:%S.%f',
                    columns=["id", "timestamp", "type", "prob", "amp", "event_index", "gamma_score"])
# Out:
#   0%|          | 0/24 [00:00<?, ?it/s]
# Associating 138 clusters with 31 CPUs
# ..........................................................................................................................................
#   4%|▍         | 1/24 [00:02<00:49,  2.16s/it]
# Associating 154 clusters with 31 CPUs
# .................................................................
# Associated 100 events
# .........................................................................................
#   8%|▊         | 2/24 [00:04<00:48,  2.20s/it]
# Associating 137 clusters with 31 CPUs
# ..................................................................
# Associated 200 events.
# ......................................................................
#  12%|█▎        | 3/24 [00:06<00:46,  2.20s/it]
# Associating 147 clusters with 31 CPUs
# .................................................................................
# Associated 300 events..
# ................................................................
#  17%|█▋        | 4/24 [00:09<00:46,  2.33s/it]
# Associating 142 clusters with 31 CPUs
# ........................................................................................................
# Associated 400 events
# ......................................
#  21%|██        | 5/24 [00:11<00:42,  2.25s/it]
# Associating 145 clusters with 31 CPUs
# .................................................................................................................................................
# Associated 500 events
#  25%|██▌       | 6/24 [00:13<00:42,  2.34s/it]
# Associating 135 clusters with 31 CPUs
# .......................................................................................................................................
#  29%|██▉       | 7/24 [00:15<00:38,  2.25s/it]
# Associating 137 clusters with 31 CPUs
# ............................................................................................
# Associated 600 events...
# ..........................................
#  33%|███▎      | 8/24 [00:17<00:34,  2.18s/it]
# Associating 140 clusters with 31 CPUs
# ............................................................................................................................................
#  38%|███▊      | 9/24 [00:19<00:30,  2.02s/it]
# Associating 144 clusters with 31 CPUs
# ...........................................................
# Associated 700 events
# .....................................................................................
#  42%|████▏     | 10/24 [00:22<00:32,  2.29s/it]
# Associating 133 clusters with 31 CPUs
# ...................................................................................................................
# Associated 800 events
# ..................
#  46%|████▌     | 11/24 [00:24<00:28,  2.20s/it]
# Associating 138 clusters with 31 CPUs
# ..........................................................................................................................................
# Associated 900 events
#  50%|█████     | 12/24 [00:27<00:29,  2.44s/it]
# Associating 133 clusters with 31 CPUs
# .....................................................................................................................................
#  54%|█████▍    | 13/24 [00:30<00:27,  2.54s/it]
# Associating 146 clusters with 31 CPUs
# ....................................................................................................
# Associated 1000 events
# ..............................................
#  58%|█████▊    | 14/24 [00:31<00:21,  2.19s/it]
# Associating 147 clusters with 31 CPUs
# ...................................................................................................................................................
# Associated 1100 events
#  62%|██████▎   | 15/24 [00:33<00:18,  2.11s/it]
# Associating 134 clusters with 31 CPUs
# ......................................................................................................................................
#  67%|██████▋   | 16/24 [00:35<00:16,  2.07s/it]
# Associating 133 clusters with 31 CPUs
# .....................................................................................................................................
# Associated 1200 events
#  71%|███████   | 17/24 [00:37<00:13,  1.92s/it]
# Associating 140 clusters with 31 CPUs
# ............................................................................................................................................
#  75%|███████▌  | 18/24 [00:39<00:11,  1.94s/it]
# Associating 124 clusters with 31 CPUs
# ........................................................................
# Associated 1300 events.
# ...................................................
#  79%|███████▉  | 19/24 [00:40<00:08,  1.79s/it]
# Associating 134 clusters with 31 CPUs
# ......................................................................................................................................
# Associated 1400 events
#  83%|████████▎ | 20/24 [00:42<00:07,  1.87s/it]
# Associating 140 clusters with 31 CPUs
# ............................................................................................................................................
#  88%|████████▊ | 21/24 [00:44<00:05,  1.95s/it]
# Associating 132 clusters with 31 CPUs
# ...................................................................
# Associated 1500 events
# .................................................................
# Initialization 1 did not converge.
#  92%|█████████▏| 22/24 [00:47<00:04,  2.36s/it]
# Associating 136 clusters with 31 CPUs
# .....................................................................................................
# Associated 1600 events..
# .................................
#  96%|█████████▌| 23/24 [00:50<00:02,  2.31s/it]
# Associating 140 clusters with 31 CPUs
# ............................................................................................................................................
# Associated 1700 events
# 100%|██████████| 24/24 [00:52<00:00,  2.19s/it]

# %% [markdown]
# ### Run HypoInverse
# Convert station file, phase file, and run single event location with HypoInverse (https://www.usgs.gov/software/hypoinverse-earthquake-location)
#
# ##### Reference:
# Klein, Fred W. User's guide to HYPOINVERSE-2000, a Fortran program to solve for earthquake locations and magnitudes. No. 2002-171. US Geological Survey, 2002.
#
# ##### Convert station file format

# %%
import numpy as np
import pandas as pd
from tqdm import tqdm

stations = pd.read_csv("./stations.csv", sep="\t")
converted_hypoinverse = []
converted_hypoDD = {}

for i in tqdm(range(len(stations))):

    network_code, station_code, comp_code, channel_code = stations.iloc[i]['station'].split('.')
    station_weight = " "
    lat_degree = int(stations.iloc[i]['latitude'])
    lat_minute = (stations.iloc[i]['latitude'] - lat_degree) * 60
    north = "N" if lat_degree >= 0 else "S"
    lng_degree = int(stations.iloc[i]['longitude'])
    lng_minute = (stations.iloc[i]['longitude'] - lng_degree) * 60
    west = "W" if lng_degree <= 0 else "E"
    elevation = stations.iloc[i]['elevation(m)']
    line_hypoinverse = f"{station_code:<5} {network_code:<2} {comp_code[:-1]:<1}{channel_code:<3} {station_weight}{abs(lat_degree):2.0f} {abs(lat_minute):7.4f}{north}{abs(lng_degree):3.0f} {abs(lng_minute):7.4f}{west}{elevation:4.0f}\n"
    converted_hypoinverse.append(line_hypoinverse)
    converted_hypoDD[f"{station_code}"] = f"{network_code:<2}{station_code:<5} {stations.iloc[i]['latitude']:.3f} {stations.iloc[i]['longitude']:.3f} {elevation:4.0f}\n"

out_file = 'stations_hypoinverse.dat'
with open(out_file, 'w') as f:
    f.writelines(converted_hypoinverse)

out_file = 'stations_hypoDD.dat'
with open(out_file, 'w') as f:
    for k, v in converted_hypoDD.items():
        f.write(v)
# Out:
# 100%|██████████| 24/24 [00:00<00:00, 1904.01it/s]

# %% [markdown]
# ##### Write phase file in HypoInverse format:
# Read GaMMA associated events and write in HypoInverse phase input format

# %%
from datetime import datetime

stations = pd.read_csv("./stations.csv", sep="\t")
stations['net']=stations['station'].apply(lambda x: x.split('.')[0])
stations['sta']=stations['station'].apply(lambda x: x.split('.')[1])
stations['cha']=stations['station'].apply(lambda x: x.split('.')[3])

picks = pd.read_csv(GMMAResultDir+"/picks_gamma.csv", sep="\t")
events = pd.read_csv(GMMAResultDir+"/catalog_gamma.csv", sep="\t")

events["match_id"] = events["event_index"]
picks["match_id"] = picks["event_index"]
events.sort_values(by="time", inplace=True, ignore_index=True)

out_file = open("./hypoInv/hypoInput.arc", "w")


picks_by_event = picks.groupby("match_id").groups
for i in tqdm(range(len(events))):

    event = events.iloc[i]
    event_time = datetime.strptime(event["time"], "%Y-%m-%dT%H:%M:%S.%f").strftime("%Y%m%d%H%M%S%f")[:-4]
    lat_degree = int(event["latitude"])
    lat_minute = (event["latitude"] - lat_degree) * 60 * 100
    south = "S" if lat_degree <= 0 else " "
    lng_degree = int(event["longitude"])
    lng_minute = (event["longitude"] - lng_degree) * 60 * 100
    east = "E" if lng_degree >= 0 else " "
    depth = event["depth_km"]
    if np.sum(picks[picks["event_index"]==events.iloc[i]['match_id']]['type']=='p')==0:
        continue
    event_line = f"{event_time}{abs(lat_degree):2d}{south}{abs(lat_minute):4.0f}{abs(lng_degree):3d}{east}{abs(lng_minute):4.0f}{depth:5.0f}"
    out_file.write(event_line + "\n")

    picks_idx = picks_by_event[event["match_id"]]
    for j in picks_idx:
        pick = picks.iloc[j]
        station_code = pick['id']
        network_code = stations['net'][stations['sta'] == pick['id']].iloc[0]
        comp_code = ''
        channel_code = stations['cha'][stations['sta'] == pick['id']].iloc[0]
        phase_type = pick['type']
        phase_weight = min(max(int((1 - pick['prob']) / (1 - 0.3) * 4) - 1, 0), 3)
        pick_time = datetime.strptime(pick["timestamp"], "%Y-%m-%dT%H:%M:%S.%f")
        phase_time_minute = pick_time.strftime("%Y%m%d%H%M")
        phase_time_second = pick_time.strftime("%S%f")[:-4]
        tmp_line = f"{station_code:<5}{network_code:<2} {comp_code:<1}{channel_code:<3}"
        if phase_type.upper() == 'P':
            pick_line = f"{tmp_line:<13} P {phase_weight:<1d}{phase_time_minute} {phase_time_second}"
        elif phase_type.upper() == 'S':
            pick_line = f"{tmp_line:<13}   4{phase_time_minute} {'':<12}{phase_time_second} S {phase_weight:<1d}"
        else:
            raise (f"Phase type error {phase_type}")
        out_file.write(pick_line + "\n")

    out_file.write("\n")
    if i > 1e5:
        break

out_file.close()
# Out:
# 100%|██████████| 1724/1724 [00:20<00:00, 85.87it/s]

# %%
events
# Out:
#                          time  magnitude  longitude  latitude  depth_km  \
# 0     2016-10-18T00:00:55.500        999     13.188    42.748     8.283
# 1     2016-10-18T00:01:43.911        999     13.161    42.840     8.360
# 2     2016-10-18T00:02:09.527        999     13.217    42.655    10.172
# 3     2016-10-18T00:02:34.955        999     13.184    42.766     7.985
# 4     2016-10-18T00:02:41.699        999     13.175    42.766     6.550
# ...                       ...        ...        ...       ...       ...
# 1719  2016-10-18T23:56:02.935        999     13.184    42.723     0.000
# 1720  2016-10-18T23:56:06.041        999     13.215    42.669    12.398
# 1721  2016-10-18T23:57:15.378        999     13.141    42.831    10.234
# 1722  2016-10-18T23:57:33.197        999     13.175    42.840     9.876
# 1723  2016-10-18T23:59:12.807        999     13.143    42.867     0.000
#
#       sigma_time  sigma_amp  cov_time_amp  event_index  gamma_score  match_id
# 0          0.221          0             0           17       10.000        17
# 1          0.210          0             0           34       37.913        34
# 2          0.672          0             0           42       25.021        42
# 3          0.203          0             0           67       18.000        67
# 4          0.261          0             0           68       38.970        68
# ...          ...        ...           ...          ...          ...       ...
# 1719       0.657          0             0         1710       11.780      1710
# 1720       0.490          0             0         1711       29.154      1711
# 1721       0.106          0             0         1715       14.865      1715
# 1722       0.601          0             0         1716       55.000      1716
# 1723       0.568          0             0         1692       11.929      1692
#
# [1724 rows x 11 columns]

# %% [markdown]
# ##### Run HypoInverse:
# The parameter file is in /hypoInv/hyp_elevation.command
#
# You may need to change velocity model, distance weighting, residual weighting, trial depth, mininum number of stations.
# Details see HypoInverse user guide (https://www.usgs.gov/software/hypoinverse-earthquake-location).

# %%
# !./hypoInv/source/hyp1.40 < ./hypoInv/hyp_elevation.command
# Out:
#  HYPOINVERSE 2000 STARTING
# 6/2014 VERSION 1.40 (geoid depth possible)
#  COMMAND?  COMMAND?  COMMAND?  COMMAND?  COMMAND?  COMMAND?  COMMAND?  COMMAND?  COMMAND?  COMMAND?  COMMAND?  COMMAND?  COMMAND?  COMMAND?     24 STATIONS READ IN.
#  COMMAND?  COMMAND?   Read in crustal model(s):
#  COMMAND?  COMMAND?  COMMAND?  COMMAND?  COMMAND?  COMMAND?  COMMAND?   FIND INPUT PHASE FILE TYPE & SET PHS(COP) & ARC(CAR) FORMATS
#   INPUT IS A HYPOINVERSE ARCHIVE-2000 FILE, NO SHADOWS
#   SETTING FORMATS COP 3, CAR 1
#  COMMAND?  COMMAND?  COMMAND?  COMMAND?  COMMAND?  COMMAND?  COMMAND?   SEQ ---DATE--- TIME REMARK -LAT-  --LON-  DEPTH  RMS PMAG  NUM  ERH  ERZ  ID
#     1 2016-10-18  0:00       42 44   13 11   1.96 0.05  0.0    8  0.3  0.8         0
#     2 2016-10-18  0:01       42 50   13 10   4.09 0.14  0.0   35  0.2  1.1         0
#     3 2016-10-18  0:02       42 40   13 14   3.46 0.46  0.0   26  0.9  3.0         0
#     4 2016-10-18  0:02       42 46   13 10   5.11 0.11  0.0   15  0.4  0.5         0
#     5 2016-10-18  0:02       42 45   13 10   3.00 0.13  0.0   33  0.2  0.5         0
#     6 2016-10-18  0:02       42 54   13 16   2.56 0.14  0.0   40  0.2  0.6         0
#     7 2016-10-18  0:03       42 43   13 13  10.33 0.20  0.0   19  0.5  0.8         0
#     8 2016-10-18  0:03       42 45   13 10   6.35 0.16  0.0   13  0.4  0.8         0
#     9 2016-10-18  0:04       42 54   13 16   4.51 0.11  0.0   18  0.3  1.1         0
#    10 2016-10-18  0:04       42 45   13 11   6.24 0.26  0.0   20  0.5  1.1         0
#    11 2016-10-18  0:04     # 42 36   13  7   3.12 0.03  0.0    4  1.4  5.6         0
#    12 2016-10-18  0:05       42 31   13 15   3.84 0.07  0.0   16  0.2  0.5         0
#    13 2016-10-18  0:05       42 50   13 15   9.71 0.49  0.0   16  1.2  2.2         0
#    14 2016-10-18  0:06       42 39   13 16   4.12 0.33  0.0    9  1.3  5.0         0
#    15 2016-10-18  0:06       42 55   13 16   1.35 0.29  0.0   11  1.1  1.8         0
#   SEQ ---DATE--- TIME REMARK -LAT-  --LON-  DEPTH  RMS PMAG  NUM  ERH  ERZ  ID
#    16 2016-10-18  0:07       42 39   13 19   5.09 0.12  0.0   26  0.2  0.9         0
#    17 2016-10-18  0:08       42 46   13 17   8.72 0.18  0.0   11  1.0  1.4         0
#    18 2016-10-18  0:08       42 35   13 18   4.77 0.08  0.0    9  0.4  0.8         0
#    19 2016-10-18  0:08       42 33   13 15   4.82 0.10  0.0   17  0.3  0.9         0
#    20 2016-10-18  0:08     # 42 55   13 16   2.22 0.12  0.0   12  0.4  2.9         0
#    21 2016-10-18  0:09       42 45   13 11   5.71 0.15  0.0   18  0.3  0.7         0
#    22 2016-10-18  0:10       42 47   13  5   3.92 0.09  0.0    7  0.4  0.6         0
#    23 2016-10-18  0:12       42 46   13 10   3.94 0.19  0.0   15  0.4  0.5         0
#    24 2016-10-18  0:12       42 41   13 18   8.71 0.17  0.0   12  0.8  1.4         0
#    25 2016-10-18  0:12     # 42 51   13 15   4.75 0.17  0.0    9  0.5  1.7         0
#    26 2016-10-18  0:13       42 38   13 18   4.88 0.10  0.0   16  0.3  0.7         0
#    27 2016-10-18  0:13       42 43   13 14  10.75 0.17  0.0   12  1.1  0.7         0
#    28 2016-10-18  0:14       42 54   13 16   1.70 0.16  0.0   20  0.3  0.8         0
#    29 2016-10-18  0:15       42 40   13 14   7.30 0.14  0.0   13  0.5  0.7         0
#    30 2016-10-18  0:15       42 52   13  4   1.80 0.10  0.0   10  0.3  0.6         0
#   SEQ ---DATE--- TIME REMARK -LAT-  --LON-  DEPTH  RMS PMAG  NUM  ERH  ERZ  ID
#    31 2016-10-18  0:16       42 52   13 13   2.43 0.15  0.0   17  0.3  1.2         0
#    32 2016-10-18  0:17       42 47   13  9   0.19 0.24  0.0   21  0.3  0.9         0
#    33 2016-10-18  0:18       42 47   13  9   0.19 0.41  0.0   27  0.5  1.1         0
#    34 2016-10-18  0:20       42 44   13 12   7.63 0.14  0.0   21  0.3  0.7         0
#    35 2016-10-18  0:20       42 51   13  4   5.29 0.12  0.0   31  0.3  1.0         0
#    36 2016-10-18  0:23       42 48   13 11   8.02 0.23  0.0   19  0.4  0.9         0
#    37 2016-10-18  0:23     # 42 50   13 13   3.31 0.68  0.0   11  1.5  5.6         0
#    38 2016-10-18  0:23       42 46   13  8   8.05 0.14  0.0   26  0.2  0.5         0
#    39 2016-10-18  0:24       42 48   13 14   2.97 0.11  0.0   37  0.2  0.4         0
#    40 2016-10-18  0:24       42 54   13 15   3.95 0.14  0.0   23  0.2  0.4         0
#    41 2016-10-18  0:24     - 42 53   13 14   2.02 0.18  0.0   15  0.3 16.7         0
#    42 2016-10-18  0:25       42 42   13 18   4.48 0.14  0.0    9  1.3  2.1         0
#    43 2016-10-18  0:25       42 52   13 14   6.29 0.04  0.0    6  0.3  1.1         0
#    44 2016-10-18  0:26     # 42 54   13 14   2.34 0.17  0.0    9  0.9 10.7         0
#    45 2016-10-18  0:26       42 53   13 15   2.44 0.15  0.0   12  0.4  4.5         0
#   SEQ ---DATE--- TIME REMARK -LAT-  --LON-  DEPTH  RMS PMAG  NUM  ERH  ERZ  ID
#    46 2016-10-18  0:26       42 41   13 13   8.93 0.23  0.0   30  0.4  0.8         0
#    47 2016-10-18  0:28       42 44   13 11   5.71 0.15  0.0   22  0.3  1.0         0
#    48 2016-10-18  0:28       42 45   13 11   4.56 0.13  0.0   31  0.2  1.0         0
#    49 2016-10-18  0:28       42 48   13 11   8.80 0.21  0.0   37  0.3  0.7         0
#    50 2016-10-18  0:29       42 44   13 11   5.91 0.15  0.0   23  0.3  1.0         0
#    51 2016-10-18  0:30       42 45   13  8   7.32 0.14  0.0    9  0.6  1.2         0
#    52 2016-10-18  0:32     # 42 53   13  9   1.72 0.11  0.0    8  1.1  1.9         0
#    53 2016-10-18  0:32     # 42 55   13 16   2.82 0.15  0.0   13  0.3  2.3         0
#    54 2016-10-18  0:33       42 33   13 22   1.48 0.08  0.0    6  0.5  0.9         0
#    55 2016-10-18  0:33       42 51   13 14   5.94 0.11  0.0   10  0.6  0.9         0
#    56 2016-10-18  0:33       42 34   13 15   6.65 0.29  0.0   12  0.8  1.3         0
#    57 2016-10-18  0:34       42 46   13  9   0.25 0.10  0.0   14  0.3  0.5         0
#    58 2016-10-18  0:35       42 53   13 14   2.88 0.16  0.0   17  0.3  1.1         0
#    59 2016-10-18  0:36       42 33   13 18   6.03 0.13  0.0   29  0.2  0.5         0
#    60 2016-10-18  0:37       42 42   13  8  12.81 0.40  0.0   16  1.1  1.5         0
#   SEQ ---DATE--- TIME REMARK -LAT-  --LON-  DEPTH  RMS PMAG  NUM  ERH  ERZ  ID
#    61 2016-10-18  0:38       42 45   13 15  10.77 0.19  0.0   17  0.4  0.8         0
#    62 2016-10-18  0:39       42 38   13 12   7.34 0.08  0.0   15  0.3  0.4         0
#    63 2016-10-18  0:39       42 44   13 10   3.30 0.25  0.0   25  0.3  0.8         0
#    64 2016-10-18  0:39       42 54   13 14   1.86 0.18  0.0   20  0.3  0.7         0
#    65 2016-10-18  0:40       42 56   13 16   1.86 0.08  0.0    9  0.4  0.5         0
#    66 2016-10-18  0:40       42 43   13 13  10.26 0.22  0.0   24  0.4  0.9         0
#    67 2016-10-18  0:41       42 49   13 14   3.85 0.13  0.0   40  0.2  0.4         0
#    68 2016-10-18  0:42       42 51   13  4   5.02 0.12  0.0   12  0.4  1.3         0
#    69 2016-10-18  0:43       42 48   13 11   4.54 0.53  0.0   23  0.8  2.1         0
#    70 2016-10-18  0:43       42 52   13  7   2.23 0.08  0.0   10  0.8  1.0         0
#    71 2016-10-18  0:44       42 35   13 18   2.67 0.07  0.0   11  0.3  0.3         0
#    72 2016-10-18  0:44       42 55   13 16   4.05 0.13  0.0   22  0.3  0.9         0
#    73 2016-10-18  0:44       42 55   13 12   3.64 0.14  0.0   29  0.2  0.6         0
#    74 2016-10-18  0:46       42 51   13 16   3.78 0.15  0.0   28  0.3  0.4         0
#    75 2016-10-18  0:46       42 41   13 11   9.70 0.14  0.0   15  0.4  0.5         0
#   SEQ ---DATE--- TIME REMARK -LAT-  --LON-  DEPTH  RMS PMAG  NUM  ERH  ERZ  ID
#    76 2016-10-18  0:47       42 52   13 10   2.83 0.13  0.0   31  0.2  0.5         0
#    77 2016-10-18  0:48       42 45   13 12   4.69 0.13  0.0   35  0.2  0.8         0
#    78 2016-10-18  0:48       42 52   13 14   4.80 0.15  0.0   10  0.4  1.7         0
#    79 2016-10-18  0:49       42 52   13 15   4.14 0.13  0.0   16  0.3  0.9         0
#    80 2016-10-18  0:49       42 47   13 16   8.32 0.18  0.0   12  0.5  1.1         0
#    81 2016-10-18  0:50       42 36   13 16   4.51 0.14  0.0   11  1.1  1.4         0
#    82 2016-10-18  0:50       42 50   12 57   7.41 0.09  0.0   18  0.3  0.4         0
#    83 2016-10-18  0:51       42 45   13 12   4.10 0.12  0.0   25  0.2  0.8         0
#    84 2016-10-18  0:51       42 33   13 14   1.90 0.09  0.0   10  0.4  0.7         0
#    85 2016-10-18  0:52       42 46   13  9   1.99 0.29  0.0   22  0.7  0.4         0
#    86 2016-10-18  0:54       42 37   13 18   6.34 0.24  0.0   19  0.4  1.0         0
#    87 2016-10-18  0:56       42 45   13 13   8.42 0.12  0.0   19  0.3  0.6         0
#    88 2016-10-18  0:56       42 45   13  7   2.27 0.04  0.0    8  1.0  2.3         0
#    89 2016-10-18  0:57       42 48   13 13   4.98 0.17  0.0   39  0.2  0.9         0
#    90 2016-10-18  0:58       42 48   13 13   3.63 0.20  0.0   15  0.4  0.8         0
#   SEQ ---DATE--- TIME REMARK -LAT-  --LON-  DEPTH  RMS PMAG  NUM  ERH  ERZ  ID
#    91 2016-10-18  0:59       42 49   13 15   4.37 0.15  0.0   19  0.3  0.8         0
#    92 2016-10-18  1:00       42 48   13  4   3.77 0.15  0.0   17  0.3  0.7         0
#    93 2016-10-18  1:00       42 45   13 11   2.83 0.15  0.0   34  0.2  0.5         0
#    94 2016-10-18  1:01     # 42 34   13 15   0.13 0.32  0.0    7  8.5 10.6         0
#    95 2016-10-18  1:02     # 42 43   13 16   3.83 0.93  0.0   13  3.0  6.0         0
#    96 2016-10-18  1:02       42 44   13 12   5.16 0.14  0.0   31  0.2  0.9         0
#    97 2016-10-18  1:03       42 50   13 11   3.94 0.12  0.0   43  0.2  0.5         0
#    98 2016-10-18  1:04       42 45   13 14   9.90 0.71  0.0   25  1.2  2.8         0
#    99 2016-10-18  1:04     - 42 27   14 52   5.56 0.28  0.0   23 19.6  7.0         0
#   100 2016-10-18  1:05     # 42 49   13 11   2.50 0.18  0.0    9  0.6  3.1         0
#   101 2016-10-18  1:05       42 43   13 14  10.19 0.22  0.0   24  0.4  0.8         0
#   102 2016-10-18  1:06       42 46   13 12   4.24 0.44  0.0   15  0.9  1.9         0
#   103 2016-10-18  1:06       42 42   13 15  10.79 0.18  0.0   14  1.1  0.8         0
#   104 2016-10-18  1:07       42 43   13 14  10.81 0.18  0.0   13  0.8  0.7         0
#   105 2016-10-18  1:07       42 50   13 11   3.13 0.18  0.0   22  0.4  1.3         0
#   SEQ ---DATE--- TIME REMARK -LAT-  --LON-  DEPTH  RMS PMAG  NUM  ERH  ERZ  ID
#   106 2016-10-18  1:08       42 35   13 18   3.20 0.12  0.0   29  0.2  0.3         0
#   107 2016-10-18  1:09       42 54   13 15   3.95 0.12  0.0   26  0.3  0.4         0
#   108 2016-10-18  1:09       42 45   13 11   5.04 0.25  0.0   27  0.4  1.2         0
#   109 2016-10-18  1:10       42 39   13 16   8.56 0.13  0.0   15  0.4  0.7         0
#   110 2016-10-18  1:10       42 52   13  8   4.45 0.14  0.0   20  0.3  1.0         0
#   111 2016-10-18  1:12       42 51   13 12   5.43 0.18  0.0   26  0.3  1.2         0
#   112 2016-10-18  1:13     # 42 39   13 16   3.03 0.18  0.0    9  0.8  2.7         0
#   113 2016-10-18  1:14       42 53   13 14   4.39 0.10  0.0    9  0.5  1.7         0
#   114 2016-10-18  1:14       42 45   13  7   6.62 0.20  0.0    8  1.0  1.2         0
#   115 2016-10-18  1:15       42 52   13  4   4.31 0.12  0.0   14  0.6  1.4         0
#   116 2016-10-18  1:17       42 49   13 14   4.43 0.25  0.0   13  0.7  1.9         0
#   117 2016-10-18  1:17       42 53   13 14   7.18 0.30  0.0   16  0.7  1.5         0
#   118 2016-10-18  1:17       42 37   13 13   8.16 0.07  0.0    9  0.4  0.5         0
#   119 2016-10-18  1:17       42 45   13 11   8.20 0.13  0.0   37  0.2  0.5         0
#   120 2016-10-18  1:18       42 49   13 13   6.34 0.17  0.0   18  0.5  1.1         0
#   SEQ ---DATE--- TIME REMARK -LAT-  --LON-  DEPTH  RMS PMAG  NUM  ERH  ERZ  ID
#   121 2016-10-18  1:19       42 40   13 16   3.75 0.13  0.0   12  0.4  0.9         0
#   122 2016-10-18  1:19       42 54   13 14   2.67 0.13  0.0   19  0.2  1.1         0
#   123 2016-10-18  1:19       42 46   13 12   4.81 0.18  0.0   28  0.3  0.8         0
#   124 2016-10-18  1:19       42 44   13 10  11.82 0.20  0.0   25  0.3  0.8         0
#   125 2016-10-18  1:20       42 53   13 14   5.09 0.13  0.0   13  0.4  1.3         0
#   126 2016-10-18  1:20       42 38   13 18   1.86 0.06  0.0    7  0.5  0.8         0
#   127 2016-10-18  1:21     # 42 48   13  8   0.22 0.24  0.0    8  0.7  2.1         0
#   128 2016-10-18  1:21       43  3   13 13   2.25 0.08  0.0   11  0.5  1.0         0
#   129 2016-10-18  1:22       42 44   13 10  11.52 0.15  0.0   18  0.4  0.6         0
#   130 2016-10-18  1:23       42 45   13 12   2.86 0.18  0.0    8  0.7  2.2         0
#   131 2016-10-18  1:23     # 42 40   13  4   3.74 1.28  0.0   12 11.4 16.7         0
#   132 2016-10-18  1:23     # 42 53   13 15   1.60 0.14  0.0    9  0.4  2.0         0
#   133 2016-10-18  1:24       42 52   13  5   4.51 0.17  0.0   18  0.4  1.7         0
#   134 2016-10-18  1:24       42 54   13 15   3.07 0.16  0.0   34  0.2  0.8         0
#   135 2016-10-18  1:25     # 42 56   13 15   4.65 0.87  0.0   13  2.7 10.7         0
#   SEQ ---DATE--- TIME REMARK -LAT-  --LON-  DEPTH  RMS PMAG  NUM  ERH  ERZ  ID
#   136 2016-10-18  1:26       42 54   13 12   1.96 0.12  0.0   11  1.0  1.6         0
#   137 2016-10-18  1:27       42 54   13 11   4.19 0.13  0.0   20  0.3  1.1         0
#   138 2016-10-18  1:27       42 40   13 17   5.39 0.10  0.0   12  0.3  1.0         0
#   139 2016-10-18  1:28       42 47   13  9   3.03 0.11  0.0   15  0.4  0.3         0
#   140 2016-10-18  1:29       42 46   13  9   0.19 0.64  0.0   18  1.3  3.2         0
#   141 2016-10-18  1:29       42 47   13  9   4.17 0.13  0.0   21  0.2  0.4         0
#   142 2016-10-18  1:30       42 45   13 11   5.77 0.14  0.0   19  0.3  0.7         0
#   143 2016-10-18  1:30       42 41   13 18   3.42 0.15  0.0   19  0.3  1.5         0
#   144 2016-10-18  1:31       42 44   13 11   6.50 0.05  0.0    8  0.4  1.1         0
#   145 2016-10-18  1:31       42 53   13 14   4.03 0.15  0.0   19  0.3  1.5         0
#   146 2016-10-18  1:32       42 45   13 12   6.59 0.14  0.0   43  0.2  0.7         0
#   147 2016-10-18  1:32     # 42 54   13 15   0.08 0.57  0.0   15  0.8  2.1         0
#   148 2016-10-18  1:33       42 54   13 16   4.20 0.11  0.0   13  0.3  1.6         0
#   149 2016-10-18  1:33     # 42 41   13 13   4.66 0.86  0.0   10  3.9 19.4         0
#   150 2016-10-18  1:34       42 46   13 13   7.20 0.16  0.0   19  0.4  0.8         0
#   SEQ ---DATE--- TIME REMARK -LAT-  --LON-  DEPTH  RMS PMAG  NUM  ERH  ERZ  ID
#   151 2016-10-18  1:34       42 39   13 21   3.99 0.14  0.0   19  0.3  0.6         0
#   152 2016-10-18  1:36     # 42 51   13 15   4.09 1.10  0.0   12  4.5 11.2         0
#   153 2016-10-18  1:37       42 45   13 11   4.57 0.13  0.0   41  0.2  0.8         0
#   154 2016-10-18  1:40       42 49   13 11   3.93 0.21  0.0   15  0.5  1.1         0
#   155 2016-10-18  1:40       42 49   13 12   5.39 0.14  0.0   36  0.2  0.6         0
#   156 2016-10-18  1:41       42 39   13 20   5.53 0.16  0.0   21  0.3  1.1         0
#   157 2016-10-18  1:42       42 55   13 15   3.60 0.13  0.0   13  0.4  1.3         0
#   158 2016-10-18  1:42       42 51   13 13   6.43 0.16  0.0   11  0.6  1.3         0
#   159 2016-10-18  1:42     # 42 52   13 10   2.07 0.13  0.0   10  0.3  4.3         0
#   160 2016-10-18  1:43       42 48   13  8   0.66 0.10  0.0   10  0.6  0.5         0
#   161 2016-10-18  1:44     # 42 53   13 10   1.97 0.35  0.0   13  1.0  2.2         0
#   162 2016-10-18  1:45       42 49   13 12   6.81 0.13  0.0   39  0.2  0.7         0
#   163 2016-10-18  1:46       42 40   13 14   5.98 0.06  0.0    8  0.4  1.0         0
#   164 2016-10-18  1:46       42 42   13 13   7.68 0.14  0.0   10  0.5  1.1         0
#   165 2016-10-18  1:47       42 52   13  5   3.73 0.10  0.0   18  0.3  0.5         0
#   SEQ ---DATE--- TIME REMARK -LAT-  --LON-  DEPTH  RMS PMAG  NUM  ERH  ERZ  ID
#   166 2016-10-18  1:48       42 46   13 12  11.59 0.43  0.0   15  1.3  1.5         0
#   167 2016-10-18  1:48       42 48   13 10   4.51 0.14  0.0   23  0.2  0.7         0
#   168 2016-10-18  1:48       42 52   13 15   2.20 0.16  0.0   18  0.3  1.4         0
#   169 2016-10-18  1:48       42 44   13 11   1.91 0.07  0.0   10  0.3  0.8         0
#   170 2016-10-18  1:49     - 42 56   13 12   1.98 0.10  0.0    8  4.3 10.1         0
#   171 2016-10-18  1:50       42 44   13 10   1.38 0.07  0.0   10  0.3  0.8         0
#   172 2016-10-18  1:53       42 38   13 19   7.48 0.10  0.0    9  0.4  1.3         0
#   173 2016-10-18  1:53       42 41   13 12   8.44 0.06  0.0    9  0.4  0.6         0
#   174 2016-10-18  1:53       42 31   13  3   1.75 0.10  0.0   11  0.3  0.5         0
#   175 2016-10-18  1:54       42 45   13 16  11.24 0.16  0.0   23  0.3  0.7         0
#   176 2016-10-18  1:54       42 39   13 19   6.27 0.14  0.0   42  0.2  0.6         0
#   177 2016-10-18  1:55       42 46   13  8   6.06 0.09  0.0   15  0.3  0.4         0
#   178 2016-10-18  1:56       42 46   13 19   7.79 0.08  0.0    8  0.5  0.9         0
#   179 2016-10-18  1:56       42 45   13 11   3.84 0.20  0.0   19  0.4  0.6         0
#   180 2016-10-18  1:56       42 49   13  9   7.87 0.16  0.0   43  0.2  0.6         0
#   SEQ ---DATE--- TIME REMARK -LAT-  --LON-  DEPTH  RMS PMAG  NUM  ERH  ERZ  ID
#   181 2016-10-18  1:57       42 53   13 16   4.29 0.13  0.0   17  0.3  1.2         0
#   182 2016-10-18  1:58     # 42 50   13 10   3.50 0.18  0.0   10  1.2  2.3         0
#   183 2016-10-18  1:58       42 49   13  3   2.35 0.08  0.0    9  0.4  1.2         0
#   184 2016-10-18  1:58       42 45   13  8   8.27 0.14  0.0   28  0.2  0.5         0
#   185 2016-10-18  1:59       42 54   13 14   2.14 0.14  0.0   20  0.2  1.2         0
#   186 2016-10-18  1:59       42 53   13 15   3.79 0.13  0.0   14  0.3  0.7         0
#   187 2016-10-18  1:59       42 51   13 12   5.99 0.17  0.0   20  0.3  1.1         0
#   188 2016-10-18  2:00       42 48   13  8   5.95 0.15  0.0   32  0.2  1.5         0
#   189 2016-10-18  2:00       42 52   13  5   4.56 0.12  0.0   12  0.5  1.3         0
#   190 2016-10-18  2:01       42 45   13 11   6.60 0.10  0.0    9  0.3  0.8         0
#   191 2016-10-18  2:01       42 41   13 14   9.24 0.14  0.0   45  0.2  0.5         0
#   192 2016-10-18  2:02       42 52   13  4   3.93 0.13  0.0   18  0.3  0.7         0
#   193 2016-10-18  2:02       42 33   13 13   6.18 0.04  0.0   10  0.4  0.8         0
#   194 2016-10-18  2:03       42 52   13  5   3.78 0.08  0.0   11  0.7  0.4         0
#   195 2016-10-18  2:04     # 42 54   13 14   2.52 0.13  0.0   13  0.3  3.1         0
#   SEQ ---DATE--- TIME REMARK -LAT-  --LON-  DEPTH  RMS PMAG  NUM  ERH  ERZ  ID
#   196 2016-10-18  2:04       42 42   13 16   8.37 0.18  0.0   10  1.4  1.2         0
#   197 2016-10-18  2:05       42 45   13 11   4.72 0.11  0.0   20  0.2  0.7         0
#   198 2016-10-18  2:07       42 47   13  9   0.20 0.30  0.0   23  0.4  1.3         0
#   199 2016-10-18  2:07     # 42 52   13 15   2.15 0.12  0.0    8  0.4  5.2         0
#   200 2016-10-18  2:08       42 44   13 12   5.23 0.14  0.0   30  0.2  0.7         0
#   201 2016-10-18  2:09       42 41   13 14   9.25 0.13  0.0   43  0.2  0.4         0
#   202 2016-10-18  2:09       42 44   13 10   6.84 0.08  0.0   11  0.3  0.7         0
#   203 2016-10-18  2:10       42 46   13  9   5.85 0.07  0.0   17  0.3  0.3         0
#   204 2016-10-18  2:10       42 52   13 14   4.13 0.14  0.0   17  0.3  1.0         0
#   205 2016-10-18  2:10       42 44   13 11   4.20 0.14  0.0   22  0.3  0.9         0
#   206 2016-10-18  2:11     # 42 51   13 15   2.12 0.14  0.0   10  1.0  5.0         0
#   207 2016-10-18  2:12       42 52   13 16   4.37 0.13  0.0   11  0.4  0.9         0
#   208 2016-10-18  2:12       42 52   13 15   0.63 0.21  0.0   18  0.3  1.6         0
#   209 2016-10-18  2:12       42 45   13  8   6.85 0.09  0.0   14  0.2  0.5         0
#   210 2016-10-18  2:12       42 35   13 18   4.50 0.11  0.0   17  0.3  0.5         0
#   SEQ ---DATE--- TIME REMARK -LAT-  --LON-  DEPTH  RMS PMAG  NUM  ERH  ERZ  ID
#   211 2016-10-18  2:14       42 51   13  8   7.81 0.12  0.0    7  0.7  1.1         0
#   212 2016-10-18  2:15       42 49   13 16   4.12 0.10  0.0   11  0.4  0.7         0
#   213 2016-10-18  2:16       42 40   13 16   4.75 0.36  0.0   14  0.8  3.6         0
#   214 2016-10-18  2:16       42 51   13 11   5.87 0.10  0.0   12  0.3  1.3         0
#   215 2016-10-18  2:17     # 42 33   13 18   0.03 0.10  0.0   10  0.4  1.1         0
#   216 2016-10-18  2:17       42 52   13 15   3.57 0.08  0.0   11  0.3  1.0         0
#   217 2016-10-18  2:17       42 39   13 13   7.30 0.14  0.0   12  0.6  0.7         0
#   218 2016-10-18  2:18       42 34   13 17   3.21 0.05  0.0    8  0.6  0.3         0
#   219 2016-10-18  2:19       42 46   13 17   9.05 0.13  0.0   20  0.3  0.5         0
#   220 2016-10-18  2:19       42 54   13 16   4.20 0.12  0.0   16  0.3  1.2         0
#   221 2016-10-18  2:19       42 51   13 16   3.99 0.13  0.0   27  0.2  0.3         0
#   222 2016-10-18  2:20       42 55   13 15   4.71 0.15  0.0   20  0.3  1.2         0
#   223 2016-10-18  2:20       42 56   13 16   2.50 0.08  0.0   10  0.4  2.0         0
#   224 2016-10-18  2:21       42 45   13  7   6.22 0.09  0.0   17  0.2  0.5         0
#   225 2016-10-18  2:21       42 52   13 14   4.63 0.13  0.0   15  0.3  0.9         0
#   SEQ ---DATE--- TIME REMARK -LAT-  --LON-  DEPTH  RMS PMAG  NUM  ERH  ERZ  ID
#   226 2016-10-18  2:21       42 45   13 18   9.89 0.13  0.0   15  0.4  0.7         0
#   227 2016-10-18  2:23       42 45   13  9   1.21 0.19  0.0   28  0.3  0.5         0
#   228 2016-10-18  2:24       42 45   13 17   9.68 0.16  0.0   31  0.3  0.6         0
#   229 2016-10-18  2:24       42 41   13 18   6.72 0.25  0.0    9  1.2  3.0         0
#   230 2016-10-18  2:24       42 46   13 10   0.96 0.20  0.0   29  0.2  0.5         0
#   231 2016-10-18  2:25       42 50   13 10   4.69 0.22  0.0   32  0.3  1.2         0
#   232 2016-10-18  2:26       42 52   13 15   4.04 0.12  0.0   10  0.4  1.3         0
#   233 2016-10-18  2:27       42 54   13 15   2.34 0.13  0.0   16  0.2  1.5         0
#   234 2016-10-18  2:28       42 39   13 15  10.59 0.12  0.0   21  0.3  0.5         0
#   235 2016-10-18  2:29       42 52   13 15   3.52 0.34  0.0   21  0.6  1.7         0
#   236 2016-10-18  2:30     # 42 54   13 16   4.08 0.12  0.0   15  0.3  1.6         0
#   237 2016-10-18  2:31       42 44   13 11   3.91 0.14  0.0   42  0.2  0.4         0
#   238 2016-10-18  2:32       42 49   13 12   5.36 0.15  0.0   40  0.2  0.8         0
#   239 2016-10-18  2:33       42 39   13 15   7.47 0.09  0.0   12  0.3  0.7         0
#   240 2016-10-18  2:34       42 39   13 15   9.46 0.11  0.0   11  0.4  0.9         0
#   SEQ ---DATE--- TIME REMARK -LAT-  --LON-  DEPTH  RMS PMAG  NUM  ERH  ERZ  ID
#   241 2016-10-18  2:35       42 51   13 13   1.99 0.23  0.0   20  0.3  1.2         0
#   242 2016-10-18  2:35       42 56   13 16   2.00 0.14  0.0   34  0.2  0.4         0
#   243 2016-10-18  2:36       42 54   13  8   7.84 0.12  0.0   15  0.4  0.5         0
#   244 2016-10-18  2:36       42 49   13  2   0.12 0.13  0.0    8  0.3  1.5         0
#   245 2016-10-18  2:37       42 49   13 11   2.98 0.20  0.0   10  0.9  2.3         0
#   246 2016-10-18  2:38       42 54   13 12   4.65 0.17  0.0   20  0.3  1.4         0
#   247 2016-10-18  2:39       42 45   13 11   3.30 0.19  0.0   29  0.3  0.7         0
#   248 2016-10-18  2:39       42 52   13  8   3.71 0.32  0.0   11  1.5  1.2         0
#   249 2016-10-18  2:40     # 42 53   13 15   4.41 0.15  0.0   15  0.3  1.6         0
#   250 2016-10-18  2:40       42 55   13 12   2.49 0.09  0.0   11  0.6  1.8         0
#   251 2016-10-18  2:41       42 51   13  4   3.36 0.16  0.0   25  0.2  0.7         0
#   252 2016-10-18  2:41       42 28   13 11   8.62 0.05  0.0   10  0.8  0.4         0
#   253 2016-10-18  2:41       42 48   13  9   4.97 0.18  0.0   41  0.3  2.0         0
#   254 2016-10-18  2:42       42 41   13 19   8.68 0.07  0.0   11  0.3  1.1         0
#   255 2016-10-18  2:42       42 35   13 14   8.43 0.13  0.0   33  0.2  0.4         0
#   SEQ ---DATE--- TIME REMARK -LAT-  --LON-  DEPTH  RMS PMAG  NUM  ERH  ERZ  ID
#   256 2016-10-18  2:42       42 45   13 11   4.20 0.15  0.0   21  0.3  1.3         0
#   257 2016-10-18  2:44       42 51   13 12   5.64 0.17  0.0   21  0.2  1.0         0
#   258 2016-10-18  2:44       42 44   13 10   4.98 0.07  0.0   11  0.2  1.0         0
#   259 2016-10-18  2:45       42 36   13 19   4.82 0.13  0.0   16  0.3  0.5         0
#   260 2016-10-18  2:46     # 42 46   13 11   1.07 0.62  0.0   12  3.8  5.8         0
#   261 2016-10-18  2:47       42 41   13 17   4.89 0.15  0.0   27  0.2  1.0         0
#   262 2016-10-18  2:47       42 54   13 14   4.88 0.10  0.0   13  0.3  1.5         0
#   263 2016-10-18  2:48       42 51   13 12   5.56 0.15  0.0   47  0.2  0.8         0
#   264 2016-10-18  2:48       42 39   13 20   6.35 0.12  0.0   19  0.3  1.0         0
#   265 2016-10-18  2:48       42 48   13 15   3.34 0.12  0.0   24  0.2  0.5         0
#   266 2016-10-18  2:49       42 38   13 12   8.77 0.13  0.0   34  0.2  0.4         0
#   267 2016-10-18  2:50       42 54   13 15   3.82 0.13  0.0   20  0.2  0.5         0
#   268 2016-10-18  2:52       42 45   13 11   3.96 0.13  0.0   13  0.4  0.5         0
#   269 2016-10-18  2:52       42 46   13  6   3.08 0.15  0.0   33  0.2  0.6         0
#   270 2016-10-18  2:53       42 51   13  9   3.92 0.09  0.0   14  0.3  0.6         0
#   SEQ ---DATE--- TIME REMARK -LAT-  --LON-  DEPTH  RMS PMAG  NUM  ERH  ERZ  ID
#   271 2016-10-18  2:53       42 45   13 11   6.01 0.15  0.0   26  0.2  0.9         0
#   272 2016-10-18  2:54       42 52   13 16   4.11 0.17  0.0   24  0.3  0.9         0
#   273 2016-10-18  2:56       42 48   13 10   1.66 0.18  0.0   38  0.2  0.6         0
#   274 2016-10-18  2:57       42 54   13 17   3.59 0.16  0.0   30  0.4  0.7         0
#   275 2016-10-18  2:57       42 54   13 16   2.74 0.13  0.0   43  0.2  0.6         0
#   276 2016-10-18  2:58       42 54   13 14   4.06 0.10  0.0   17  0.2  1.3         0
#   277 2016-10-18  2:58       42 44   13 10   5.79 0.02  0.0    8  0.4  0.7         0
#   278 2016-10-18  2:58       42 50   13  4   4.34 0.14  0.0   30  0.2  1.1         0
#   279 2016-10-18  3:00       42 55   13 14   2.47 0.12  0.0   13  0.2  2.5         0
#   280 2016-10-18  3:01     # 42 58   13 13   0.05 0.62  0.0   13  4.5  7.3         0
#   281 2016-10-18  3:01     - 42 45   13 10   1.96 0.11  0.0    8  4.7  7.9         0
#   282 2016-10-18  3:01     # 42 50   13 15   0.04 0.08  0.0   12  0.2  0.9         0
#   283 2016-10-18  3:02       42 50   13 16   0.50 0.04  0.0    9  0.3  1.1         0
#   284 2016-10-18  3:02     # 42 55   13 17   2.66 0.11  0.0   13  0.4  2.6         0
#   285 2016-10-18  3:03       42 53   13 13   3.33 0.16  0.0   18  0.3  1.2         0
#   SEQ ---DATE--- TIME REMARK -LAT-  --LON-  DEPTH  RMS PMAG  NUM  ERH  ERZ  ID
#   286 2016-10-18  3:03       42 39   13 12   8.05 0.08  0.0   10  0.7  0.5         0
#   287 2016-10-18  3:04       42 49   13 15   1.40 0.12  0.0   11  0.4  0.6         0
#   288 2016-10-18  3:06       42 48   13 14   3.90 0.12  0.0   15  0.3  0.5         0
#   289 2016-10-18  3:08       42 44   13 12   4.15 0.16  0.0   29  0.2  1.1         0
#   290 2016-10-18  3:08       42 49   13 15   1.36 0.09  0.0   11  0.3  0.6         0
#   291 2016-10-18  3:08       42 44   13 11   1.00 0.08  0.0   10  0.2  1.1         0
#   292 2016-10-18  3:09       42 45   13 11   2.92 0.13  0.0   25  0.2  0.4         0
#   293 2016-10-18  3:10       42 35   13 18   4.56 0.13  0.0   29  0.2  0.3         0
#   294 2016-10-18  3:11       42 44   13 12   4.92 0.14  0.0   28  0.2  0.8         0
#   295 2016-10-18  3:12       42 41   13 17   4.87 0.10  0.0   13  0.8  1.8         0
#   296 2016-10-18  3:12       42 41   13 17   5.87 0.16  0.0   17  0.6  1.2         0
#   297 2016-10-18  3:13       42 35   13 18   5.02 0.13  0.0   22  0.2  0.4         0
#   298 2016-10-18  3:14       42 44   13 11   2.95 0.16  0.0   29  0.2  0.5         0
#   299 2016-10-18  3:14       42 53   13 14   3.51 0.13  0.0   44  0.2  0.6         0
#   300 2016-10-18  3:15       42 38   13 12   8.53 0.11  0.0   21  0.3  0.4         0
#   SEQ ---DATE--- TIME REMARK -LAT-  --LON-  DEPTH  RMS PMAG  NUM  ERH  ERZ  ID
#   301 2016-10-18  3:15       42 51   13  5   5.74 0.12  0.0   23  0.3  0.9         0
#   302 2016-10-18  3:16       42 43   13 12   9.05 0.11  0.0   19  0.3  0.6         0
#   303 2016-10-18  3:16       42 49   13  4   4.81 0.09  0.0    7  0.5  2.3         0
#   304 2016-10-18  3:17       42 44   13 12   4.47 0.17  0.0   31  0.2  1.2         0
#   305 2016-10-18  3:17       42 52   13 14   3.85 0.17  0.0   22  0.3  0.6         0
#   306 2016-10-18  3:18       42 49   13  4   0.62 0.11  0.0    9  0.3  1.2         0
#   307 2016-10-18  3:18       42 52   13 16   3.96 0.17  0.0   41  0.2  0.4         0
#   308 2016-10-18  3:20       42 36   13 18   5.28 0.13  0.0   13  0.4  0.6         0
#   309 2016-10-18  3:20       42 32   13 16   9.41 0.16  0.0   44  0.2  0.5         0
#   310 2016-10-18  3:20       42 52   13 16   4.58 0.16  0.0   15  0.3  0.9         0
#   311 2016-10-18  3:21       42 42   13 14   8.92 0.14  0.0   36  0.2  0.5         0
#   312 2016-10-18  3:21     # 42 44   13 18   4.11 0.10  0.0   12  0.3  3.0         0
#   313 2016-10-18  3:22       42 52   13 15   4.60 0.11  0.0   14  0.4  0.8         0
#   314 2016-10-18  3:24       42 54   13 16   3.06 0.17  0.0   28  0.3  1.1         0
#   315 2016-10-18  3:24       42 44   13  6   1.22 0.68  0.0   12  1.7  2.1         0
#   SEQ ---DATE--- TIME REMARK -LAT-  --LON-  DEPTH  RMS PMAG  NUM  ERH  ERZ  ID
#   316 2016-10-18  3:25       42 55   13 16   1.84 0.09  0.0   11  0.3  0.6         0
#   317 2016-10-18  3:25       42 51   13 14   4.73 0.07  0.0   10  0.4  3.1         0
#   318 2016-10-18  3:26       42 45   13 11   3.94 0.13  0.0   36  0.2  0.4         0
#   319 2016-10-18  3:28       42 46   13  9   3.73 0.15  0.0   26  0.2  0.4         0
#   320 2016-10-18  3:28       42 47   13 16  11.42 0.11  0.0   15  0.3  0.7         0
#   321 2016-10-18  3:30       42 47   13 15   5.06 0.61  0.0   10  1.4  6.1         0
#   322 2016-10-18  3:30       42 32   13 15   6.67 0.08  0.0    8  0.8  1.2         0
#   323 2016-10-18  3:31       42 49   13 12   3.91 0.41  0.0   13  0.7  2.0         0
#   324 2016-10-18  3:31       42 44   13 12   4.90 0.15  0.0   18  0.3  1.4         0
#   325 2016-10-18  3:31       42 49   13 12  10.22 0.19  0.0   29  0.3  0.8         0
#   326 2016-10-18  3:32       42 53   13 14   2.85 0.10  0.0   14  0.2  0.7         0
#   327 2016-10-18  3:32       42 52   13 14   3.90 0.15  0.0   17  0.3  0.5         0
#   328 2016-10-18  3:33       42 32   13 16   9.32 0.12  0.0   44  0.2  0.4         0
#   329 2016-10-18  3:33       42 51   13 14   4.30 0.12  0.0   17  0.3  0.9         0
#   330 2016-10-18  3:35     # 42 41   13  8   4.76 0.65  0.0    9  3.1 16.1         0
#   SEQ ---DATE--- TIME REMARK -LAT-  --LON-  DEPTH  RMS PMAG  NUM  ERH  ERZ  ID
#   331 2016-10-18  3:36       42 45   13 18   8.65 0.18  0.0   13  0.5  0.9         0
#   332 2016-10-18  3:36       42 51   13 13   4.85 0.18  0.0   17  0.3  1.5         0
#   333 2016-10-18  3:36     # 42 55   13 16   0.04 0.52  0.0   17  0.8  2.5         0
#   334 2016-10-18  3:37       42 50   13 16   1.72 0.27  0.0   29  0.3  0.7         0
#   335 2016-10-18  3:37       42 45   13 10   8.88 0.13  0.0   41  0.2  0.5         0
#   336 2016-10-18  3:38       42 52   13  5   3.23 0.12  0.0   23  0.3  0.6         0
#   337 2016-10-18  3:38       42 45   13 10   8.80 0.13  0.0   36  0.2  0.5         0
#   338 2016-10-18  3:40     # 42 49   13 19   2.86 0.98  0.0   13  3.6  2.6         0
#   339 2016-10-18  3:41       42 48   13 10   3.20 0.09  0.0   14  0.3  0.5         0
#   340 2016-10-18  3:41       42 46   13 15  11.91 0.14  0.0   32  0.3  0.5         0
#   341 2016-10-18  3:42       42 49   13  9   7.14 0.14  0.0   31  0.2  0.6         0
#   342 2016-10-18  3:42       42 52   13 14   2.79 0.25  0.0   23  0.4  1.0         0
#   343 2016-10-18  3:43       42 41   13 14   9.22 0.12  0.0   44  0.2  0.4         0
#   344 2016-10-18  3:43       42 46   13  7   7.41 0.65  0.0   10  3.0  9.0         0
#   345 2016-10-18  3:44       42 53   13  3   9.81 0.40  0.0    9  2.1  3.0         0
#   SEQ ---DATE--- TIME REMARK -LAT-  --LON-  DEPTH  RMS PMAG  NUM  ERH  ERZ  ID
#   346 2016-10-18  3:44       42 47   13 14  10.69 0.11  0.0   14  0.4  0.6         0
#   347 2016-10-18  3:45       42 40   13 15   7.69 0.06  0.0    7  1.0  0.6         0
#   348 2016-10-18  3:45       42 35   13 18   2.97 0.05  0.0   13  0.2  0.2         0
#   349 2016-10-18  3:46       42 51   13 16   3.92 0.14  0.0   25  0.3  0.4         0
#   350 2016-10-18  3:46       42 51   13  9   3.63 0.19  0.0   24  0.4  0.7         0
#   351 2016-10-18  3:46     # 42 47   13  9   0.45 0.59  0.0    8  3.1  1.9         0
#   352 2016-10-18  3:46       42 50   13 12   6.00 0.53  0.0   24  1.0  4.7         0
#   353 2016-10-18  3:46       42 40   13 12   8.83 0.12  0.0   15  0.3  0.8         0
#   354 2016-10-18  3:47       42 44   13 12   4.09 0.14  0.0   19  0.2  1.2         0
#   355 2016-10-18  3:49     # 42 46   13  7   0.02 0.09  0.0    8  0.5  0.8         0
#   356 2016-10-18  3:49       42 46   13 11   5.23 0.13  0.0   25  0.2  0.5         0
#   357 2016-10-18  3:49       42 45   13 17   9.78 0.11  0.0   18  0.3  0.5         0
#   358 2016-10-18  3:50       42 52   13 15   3.16 0.20  0.0   21  0.4  1.2         0
#   359 2016-10-18  3:52     # 42 50   13  9   2.14 0.14  0.0   14  0.3  2.3         0
#   360 2016-10-18  3:52       42 51   13 10   4.71 0.14  0.0   25  0.3  1.2         0
#   SEQ ---DATE--- TIME REMARK -LAT-  --LON-  DEPTH  RMS PMAG  NUM  ERH  ERZ  ID
#   361 2016-10-18  3:53       42 58   13  2  10.15 0.13  0.0   18  0.6  0.9         0
#   362 2016-10-18  3:53       42 48   13 13   6.49 0.16  0.0   18  0.4  1.1         0
#   363 2016-10-18  3:54       42 45   13  5   5.70 0.05  0.0    8  0.5  1.0         0
#   364 2016-10-18  3:54       42 50   13  4   3.71 0.13  0.0   20  0.3  0.5         0
#   365 2016-10-18  3:55       42 55   13 16   4.07 0.12  0.0   17  0.3  1.3         0
#   366 2016-10-18  3:57       42 41   13 12   8.85 0.13  0.0   31  0.2  0.5         0
#   367 2016-10-18  3:57       42 39   13 20   7.23 0.13  0.0   18  0.2  0.8         0
#   368 2016-10-18  3:58       42 47   13 15   4.31 0.20  0.0   12  1.1  1.4         0
#   369 2016-10-18  3:58       42 47   12 58   5.33 0.09  0.0   12  0.4  0.5         0
#   370 2016-10-18  3:58       42 49   13 12   5.01 0.22  0.0   13  0.7  2.2         0
#   371 2016-10-18  3:59       42 45   13 11   2.58 0.25  0.0   13  0.8  2.3         0
#   372 2016-10-18  4:00       42 40   13 20   5.94 0.09  0.0    7  0.4  2.1         0
#   373 2016-10-18  4:00       42 42   13 13   8.42 0.14  0.0   21  0.3  0.6         0
#   374 2016-10-18  4:01       42 53   13 14   1.58 0.17  0.0   13  0.5  1.2         0
#   375 2016-10-18  4:01       42 51   13 16   4.15 0.12  0.0   16  0.4  0.6         0
#   SEQ ---DATE--- TIME REMARK -LAT-  --LON-  DEPTH  RMS PMAG  NUM  ERH  ERZ  ID
#   376 2016-10-18  4:01       42 38   13 34  13.22 0.06  0.0    8  1.9  2.4         0
#   377 2016-10-18  4:03       42 54   13 15   4.12 0.13  0.0   20  0.2  1.2         0
#   378 2016-10-18  4:04       42 54   13 15   2.78 0.15  0.0   33  0.2  0.6         0
#   379 2016-10-18  4:04       42 42   13 12  11.38 0.56  0.0   22  1.2  2.2         0
#   380 2016-10-18  4:05       42 54   13 15   3.44 0.13  0.0   44  0.2  0.6         0
#   381 2016-10-18  4:05       42 53   13 14   4.51 0.17  0.0   16  0.3  1.5         0
#   382 2016-10-18  4:05       42 58   13 10  12.87 0.14  0.0   34  0.3  0.5         0
#   383 2016-10-18  4:06       42 33   13 21  14.35 0.60  0.0    9  3.2  4.2         0
#   384 2016-10-18  4:06       42 45   13  5   6.17 0.10  0.0   15  0.3  0.7         0
#   385 2016-10-18  4:06       42 55   13 12   2.52 0.11  0.0   10  0.5  2.6         0
#   386 2016-10-18  4:07       42 52   13  5   3.73 0.12  0.0   18  0.3  0.6         0
#   387 2016-10-18  4:07       42 35   13 17   7.32 0.05  0.0   13  0.3  0.5         0
#   388 2016-10-18  4:08       42 44   13 12   5.43 0.05  0.0   11  0.2  0.9         0
#   389 2016-10-18  4:09     - 42 55   13 16   2.00 0.14  0.0   10  0.4 14.4         0
#   390 2016-10-18  4:09       42 36   13 14   7.32 0.08  0.0   13  0.4  0.6         0
#   SEQ ---DATE--- TIME REMARK -LAT-  --LON-  DEPTH  RMS PMAG  NUM  ERH  ERZ  ID
#   391 2016-10-18  4:09       42 34   13 18   3.86 0.06  0.0    9  0.4  0.3         0
#   392 2016-10-18  4:10       42 37   13 17   5.58 0.09  0.0   13  0.4  0.9         0
#   393 2016-10-18  4:10     # 42 44   13 10   0.04 0.21  0.0    9  0.4  2.6         0
#   394 2016-10-18  4:12       42 35   13 18   4.34 0.04  0.0    9  0.5  0.6         0
#   395 2016-10-18  4:12       42 52   13 14   2.70 0.21  0.0   20  0.3  1.4         0
#   396 2016-10-18  4:13       42 47   13  8   0.22 0.51  0.0   22  0.7  1.2         0
#   397 2016-10-18  4:13       42 49   13 14   0.58 0.06  0.0    9  0.3  1.0         0
#   398 2016-10-18  4:14       42 54   13 14   4.66 0.15  0.0   17  0.3  1.3         0
#   399 2016-10-18  4:14       42 54   13 15   3.29 0.12  0.0   17  0.3  1.6         0
#   400 2016-10-18  4:14       42 54   13 14   2.87 0.11  0.0   16  0.2  0.9         0
#   401 2016-10-18  4:15       42 33   13 19   6.69 0.12  0.0   12  0.5  0.8         0
#   402 2016-10-18  4:15       42 51   13  9   3.83 0.13  0.0   30  0.2  0.5         0
#   403 2016-10-18  4:15       42 45   13 13   8.38 0.11  0.0   20  0.3  0.5         0
#   404 2016-10-18  4:16     # 42 53   13 15   0.02 0.23  0.0   10  0.6  2.8         0
#   405 2016-10-18  4:16       42 52   13  5   4.10 0.09  0.0    8  0.4  1.7         0
#   SEQ ---DATE--- TIME REMARK -LAT-  --LON-  DEPTH  RMS PMAG  NUM  ERH  ERZ  ID
#   406 2016-10-18  4:16       42 54   13 12   3.83 0.09  0.0   10  1.2  1.7         0
#   407 2016-10-18  4:17       42 38   13 13   8.56 0.09  0.0   11  0.6  0.5         0
#   408 2016-10-18  4:17       42 40   13 15   5.57 0.13  0.0   38  0.2  0.5         0
#   409 2016-10-18  4:18       42 43   13 13   8.74 0.16  0.0   45  0.2  0.6         0
#   410 2016-10-18  4:20       42 54   13 16   2.26 0.15  0.0   23  0.3  1.1         0
#   411 2016-10-18  4:21       42 52   13 14   3.69 0.16  0.0   11  0.3  1.8         0
#   412 2016-10-18  4:21       42 44   13 11   4.97 0.15  0.0   33  0.2  0.9         0
#   413 2016-10-18  4:22       42 59   13  5   1.34 0.08  0.0    6  1.2  0.4         0
#   414 2016-10-18  4:23       42 53   13  9   3.14 0.15  0.0   40  0.3  0.8         0
#   415 2016-10-18  4:23       42 46   13  5   6.79 0.08  0.0   13  0.3  0.6         0
#   416 2016-10-18  4:24       42 44   13  7   6.83 0.15  0.0    7  3.1  1.2         0
#   417 2016-10-18  4:24       42 39   13 21   7.70 0.15  0.0   15  0.3  1.0         0
#   418 2016-10-18  4:25       43 16   13 10  11.38 0.21  0.0   27  0.7  1.7         0
#   419 2016-10-18  4:25     # 42 54   13 14   0.04 0.12  0.0   13  0.3  1.3         0
#   420 2016-10-18  4:25       42 45   13 14   8.17 0.10  0.0   11  0.4  0.6         0
#   SEQ ---DATE--- TIME REMARK -LAT-  --LON-  DEPTH  RMS PMAG  NUM  ERH  ERZ  ID
#   421 2016-10-18  4:26       42 49   13 13   2.82 0.14  0.0   47  0.2  0.4         0
#   422 2016-10-18  4:27       42 54   13 16   3.04 0.12  0.0   14  0.3  1.8         0
#   423 2016-10-18  4:28     # 42 54   13 16   2.67 0.13  0.0   14  0.4  2.6         0
#   424 2016-10-18  4:28       42 46   13 12   1.72 0.22  0.0   12  0.4  0.9         0
#   425 2016-10-18  4:29       42 46   13  5   7.26 0.13  0.0   21  0.3  0.6         0
#   426 2016-10-18  4:29       42 38   13 13   7.70 0.24  0.0   11  0.8  0.9         0
#   427 2016-10-18  4:29       42 48   13 12   4.32 0.15  0.0   36  0.2  0.6         0
#   428 2016-10-18  4:29       42 34   13 17   4.24 0.13  0.0   16  0.3  0.5         0
#   429 2016-10-18  4:30     # 42 53   13 13   2.35 0.15  0.0   12  0.4  5.1         0
#   430 2016-10-18  4:30       42 36   13 19   4.92 0.14  0.0   12  0.6  0.5         0
#   431 2016-10-18  4:31       42 52   13  9   5.01 0.14  0.0   19  0.3  0.9         0
#   432 2016-10-18  4:33       42 39   13 15   8.42 0.16  0.0   26  0.3  0.6         0
#   433 2016-10-18  4:34       42 52   13 14   2.32 0.16  0.0   18  0.4  1.5         0
#   434 2016-10-18  4:35       42 53   13 10   3.15 0.13  0.0   40  0.2  0.6         0
#   435 2016-10-18  4:35       42 53   13  9   2.62 0.12  0.0   26  0.2  0.5         0
#   SEQ ---DATE--- TIME REMARK -LAT-  --LON-  DEPTH  RMS PMAG  NUM  ERH  ERZ  ID
#   436 2016-10-18  4:36     # 42 52   13  4   0.75 0.15  0.0    9  0.5  1.5         0
#   437 2016-10-18  4:36       42 56   13 16   2.75 0.14  0.0   18  0.3  1.0         0
#   438 2016-10-18  4:37       42 46   13 10   2.27 0.07  0.0    8  0.6  1.0         0
#   439 2016-10-18  4:41       42 47   13 15   5.38 0.14  0.0    9  0.7  1.3         0
#   440 2016-10-18  4:42       42 58   13 21   9.10 0.11  0.0   19  0.4  0.5         0
#   441 2016-10-18  4:43       42 46   13  9   5.74 0.18  0.0   15  0.4  0.6         0
#   442 2016-10-18  4:43       42 49   13 11   4.07 0.12  0.0   23  0.2  1.2         0
#   443 2016-10-18  4:44       42 49   13  3   3.20 0.12  0.0    9  0.4  1.8         0
#   444 2016-10-18  4:45       42 42   13 19   8.62 0.11  0.0   14  0.3  0.8         0
#   445 2016-10-18  4:45     - 42 52   13 11   2.04 0.15  0.0    8  0.4 10.5         0
#   446 2016-10-18  4:47       42 43   13 14   7.04 0.20  0.0   12  0.7  1.4         0
#   447 2016-10-18  4:48       42 49   13 13   2.82 0.17  0.0   19  0.3  0.8         0
#   448 2016-10-18  4:48       42 51   13 13   2.50 0.10  0.0    8  0.4  3.7         0
#   449 2016-10-18  4:48       42 44   13 11   4.57 0.10  0.0   21  0.2  0.8         0
#   450 2016-10-18  4:49       42 55   13 16   3.16 0.12  0.0   12  0.3  1.6         0
#   SEQ ---DATE--- TIME REMARK -LAT-  --LON-  DEPTH  RMS PMAG  NUM  ERH  ERZ  ID
#   451 2016-10-18  4:49       42 34   13 19   4.67 0.09  0.0   21  0.2  0.3         0
#   452 2016-10-18  4:49       42 45   13  5   5.87 0.08  0.0   12  0.3  0.6         0
#   453 2016-10-18  4:50       42 45   13 10   2.71 0.13  0.0   21  0.2  0.5         0
#   454 2016-10-18  4:52       42 50   13 16   2.51 0.09  0.0   11  0.4  0.5         0
#   455 2016-10-18  4:52       42 52   13 17   3.15 0.14  0.0   17  0.3  0.6         0
#   456 2016-10-18  4:52       42 44   13 12   2.98 0.11  0.0   16  0.2  0.5         0
#   457 2016-10-18  4:54       42 40   13 11   8.71 0.12  0.0   22  0.3  0.5         0
#   458 2016-10-18  4:54       42 51   13 15   1.29 0.16  0.0   14  0.3  1.1         0
#   459 2016-10-18  4:54       42 38   13 20   5.61 0.12  0.0   14  0.3  1.0         0
#   460 2016-10-18  4:54       42 54   13 14   0.56 0.17  0.0   11  0.6  1.8         0
#   461 2016-10-18  4:55       42 48   13 10   4.03 0.14  0.0   13  0.4  0.7         0
#   462 2016-10-18  4:55       42 56   13 16   1.12 0.11  0.0   10  0.5  2.9         0
#   463 2016-10-18  4:55       42 46   13  9   1.65 0.17  0.0   43  0.2  0.5         0
#   464 2016-10-18  4:57     # 42 52   13 16   2.11 0.13  0.0   12  0.4  1.7         0
#   465 2016-10-18  4:58       42 53   13 14   2.20 0.11  0.0   16  0.4  2.9         0
#   SEQ ---DATE--- TIME REMARK -LAT-  --LON-  DEPTH  RMS PMAG  NUM  ERH  ERZ  ID
#   466 2016-10-18  4:58       42 54   13 15   3.78 0.14  0.0   26  0.3  0.5         0
#   467 2016-10-18  4:58       42 50   13 10   3.95 0.12  0.0   42  0.2  0.5         0
#   468 2016-10-18  4:59       42 47   13 13   4.86 0.14  0.0   28  0.2  1.1         0
#   469 2016-10-18  4:59       42 37   13 18   6.03 0.30  0.0    7  2.4  3.9         0
#   470 2016-10-18  5:00       42 52   13  5   4.30 0.10  0.0    7  0.7  1.6         0
#   471 2016-10-18  5:01     - 43 16   13  9   3.93 0.11  0.0   19  4.6 10.0         0
#   472 2016-10-18  5:02       42 51   13 14   3.66 0.15  0.0   17  0.3  0.7         0
#   473 2016-10-18  5:03       42 45   13  8   0.52 0.19  0.0   26  0.3  0.6         0
#   474 2016-10-18  5:03       42 44   13 12   5.66 0.16  0.0   19  0.4  1.2         0
#   475 2016-10-18  5:03       42 45   13 10   7.51 0.12  0.0   27  0.2  0.5         0
#   476 2016-10-18  5:05       42 52   13  6   2.47 0.12  0.0   18  0.4  0.7         0
#   477 2016-10-18  5:05     - 42 44   13  9   4.00 0.74  0.0    8 10.4 61.9         0
#   478 2016-10-18  5:05       42 52   13  6   3.72 0.12  0.0   23  0.3  0.6         0
#   479 2016-10-18  5:07       42 52   13 15   4.70 0.14  0.0   20  0.3  0.9         0
#   480 2016-10-18  5:09     # 42 42   13 10   5.95 0.55  0.0    8  8.6  5.1         0
#   SEQ ---DATE--- TIME REMARK -LAT-  --LON-  DEPTH  RMS PMAG  NUM  ERH  ERZ  ID
#   481 2016-10-18  5:09       42 46   13 15   9.73 0.90  0.0   14  2.3  5.5         0
#   482 2016-10-18  5:11       42 44   13 11   7.51 0.21  0.0   19  0.4  1.2         0
#   483 2016-10-18  5:11       42 50   13 10   5.10 0.13  0.0   29  0.2  0.8         0
#   484 2016-10-18  5:12       42 45   13 14   6.41 0.10  0.0   43  0.2  0.5         0
#   485 2016-10-18  5:14       42 47   13 14  12.08 0.57  0.0   12  1.6  2.7         0
#   486 2016-10-18  5:16       42 52   13  5   3.53 0.15  0.0   13  0.6  0.9         0
#   487 2016-10-18  5:18       42 42   13 13   8.24 0.14  0.0   32  0.2  0.5         0
#   488 2016-10-18  5:18       42 45   13 10   8.50 0.12  0.0   39  0.2  0.5         0
#   489 2016-10-18  5:19       42 49   13 14   7.25 0.35  0.0   20  0.6  2.2         0
#   490 2016-10-18  5:20       42 48   13 14   8.66 0.19  0.0   26  0.4  0.9         0
#   491 2016-10-18  5:21       42 37   13 16   6.05 0.13  0.0   16  0.4  0.7         0
#   492 2016-10-18  5:22       42 52   13 15   4.79 0.16  0.0   13  0.4  1.1         0
#   493 2016-10-18  5:24       42 49   13  9   5.71 0.19  0.0   23  0.3  0.8         0
#   494 2016-10-18  5:24       42 45   13 11   3.33 0.18  0.0   40  0.2  0.5         0
#   495 2016-10-18  5:25       42 38   13 20   6.07 0.12  0.0   16  0.3  0.9         0
#   SEQ ---DATE--- TIME REMARK -LAT-  --LON-  DEPTH  RMS PMAG  NUM  ERH  ERZ  ID
#   496 2016-10-18  5:28       42 41   13 15   6.01 0.15  0.0   14  0.6  0.9         0
#   497 2016-10-18  5:28       42 37   13 15   5.56 0.06  0.0   15  0.3  0.5         0
#   498 2016-10-18  5:28       42 48   13 17   8.96 0.13  0.0   28  0.3  0.5         0
#   499 2016-10-18  5:31       42 44   13 12   5.89 0.16  0.0   23  0.3  0.8         0
#   500 2016-10-18  5:31       42 49   13 15   3.29 0.13  0.0   31  0.2  0.5         0
#   501 2016-10-18  5:33       42 52   13 14   3.53 0.16  0.0   10  0.3  2.3         0
#   502 2016-10-18  5:33       42 50   13 11   3.05 0.16  0.0   10  0.6  4.3         0
#   503 2016-10-18  5:34       42 51   13 11   5.68 0.06  0.0   11  0.5  1.2         0
#   504 2016-10-18  5:35       42 36   13 21   5.15 0.04  0.0    8  0.6  0.4         0
#   505 2016-10-18  5:37       42 45   13 11   7.15 0.09  0.0   11  0.3  0.7         0
#   506 2016-10-18  5:38       42 48   13  9   3.62 0.17  0.0   43  0.2  0.6         0
#   507 2016-10-18  5:40       42 40   13 13   8.63 0.13  0.0   42  0.2  0.5         0
#   508 2016-10-18  5:43       42 49   13 14   4.26 0.13  0.0    9  0.5  1.1         0
#   509 2016-10-18  5:43       42 46   13 10   6.72 0.08  0.0    8  0.7  0.7         0
#   510 2016-10-18  5:45     # 42 53   13  9   1.97 0.10  0.0   11  1.2  1.7         0
#   SEQ ---DATE--- TIME REMARK -LAT-  --LON-  DEPTH  RMS PMAG  NUM  ERH  ERZ  ID
#   511 2016-10-18  5:46       42 49   13 15   3.28 0.10  0.0   13  0.2  0.8         0
#   512 2016-10-18  5:47     # 42 53   13 15   2.14 0.10  0.0    9  0.4  5.6         0
#   513 2016-10-18  5:49       42 45   13 10   4.37 0.03  0.0   11  0.2  0.7         0
#   514 2016-10-18  5:49       42 44   13 12   7.19 0.14  0.0   25  0.2  0.7         0
#   515 2016-10-18  5:50       42 55   13 16   3.90 0.14  0.0   18  0.3  0.5         0
#   516 2016-10-18  5:51       42 54   13 13   7.72 0.43  0.0   11  1.1  3.6         0
#   517 2016-10-18  5:51       42 40   13 15   9.56 0.50  0.0   18  1.0  2.2         0
#   518 2016-10-18  5:52       42 39   13  9   2.95 0.21  0.0    9  0.6  1.0         0
#   519 2016-10-18  5:53       42 45   13  9   0.33 0.13  0.0   26  0.2  0.4         0
#   520 2016-10-18  5:53       42 52   13  5   3.94 0.07  0.0   15  0.3  0.5         0
#   521 2016-10-18  5:53       42 47   13 15  11.50 0.09  0.0    9  0.6  0.7         0
#   522 2016-10-18  5:54       42 44   13 12   3.47 0.20  0.0   16  0.4  1.4         0
#   523 2016-10-18  5:54       42 41   13 12   8.76 0.13  0.0   32  0.2  0.5         0
#   524 2016-10-18  5:56     - 42 54   13 16   2.00 0.16  0.0   10  0.7 15.9         0
#   525 2016-10-18  5:58       42 45   13 11   3.88 0.15  0.0   17  0.3  0.7         0
# ...
#  1547 2016-10-18 21:43       42 48   13 13   5.00 0.18  0.0   11  0.7  1.4         0
#  1548 2016-10-18 21:44       42 54   13 14   3.35 0.14  0.0   36  0.2  0.6         0
#  1549 2016-10-18 21:45     - 42 54   13 14   2.01 0.13  0.0   12  0.3 13.4         0
#  1550 2016-10-18 21:45     - 42 54   13 14   2.02 0.15  0.0   13  0.3 14.3         0
#  1551 2016-10-18 21:46       42 47   13  8   1.13 0.19  0.0   35  0.2  0.3         0
#  1552 2016-10-18 21:46       42 39   13 12   8.49 0.14  0.0   28  0.3  0.4         0
#  1553 2016-10-18 21:47       42 41   13 15   9.18 0.11  0.0   17  0.3  0.6         0
#  1554 2016-10-18 21:47       42 48   13  9   8.59 0.47  0.0   26  0.8  1.9         0
#  1555 2016-10-18 21:48       42 37   13 18   8.21 0.12  0.0   26  0.2  0.5         0
#  1556 2016-10-18 21:49       42 50   13 10   5.71 0.18  0.0   39  0.3  0.9         0
#  1557 2016-10-18 21:50     # 42 43   13 14   2.02 0.60  0.0   19  1.1 22.1         0
#  1558 2016-10-18 21:50       42 45   13 11   4.14 0.20  0.0   24  0.3  1.0         0
#  1559 2016-10-18 21:51       42 50   13  8  19.07 0.53  0.0   13  1.2  1.5         0
#  1560 2016-10-18 21:51       42 42   13  9   7.01 0.07  0.0   10  0.3  0.7         0
#   SEQ ---DATE--- TIME REMARK -LAT-  --LON-  DEPTH  RMS PMAG  NUM  ERH  ERZ  ID
#  1561 2016-10-18 21:52       42 42   13 12   7.58 0.09  0.0   14  0.3  1.0         0
#  1562 2016-10-18 21:52       42 54   13 15   2.91 0.16  0.0   34  0.2  0.5         0
#  1563 2016-10-18 21:52       42 41   13 10   9.56 0.13  0.0   44  0.2  0.4         0
#  1564 2016-10-18 21:53       42 54   13 15   4.10 0.11  0.0   16  0.3  1.2         0
#  1565 2016-10-18 21:53     # 42 54   13 14   2.04 0.13  0.0   14  0.2  3.4         0
#  1566 2016-10-18 21:54       42 54   13 14   4.32 0.14  0.0   19  0.3  1.4         0
#  1567 2016-10-18 21:55       42 58   13  5   5.59 0.26  0.0    7  2.2  3.2         0
#  1568 2016-10-18 21:55       42 54   13 14   4.13 0.19  0.0   25  0.3  1.5         0
#  1569 2016-10-18 21:56       42 44   13 11   7.18 0.12  0.0   36  0.2  0.5         0
#  1570 2016-10-18 21:57       42 48   13  5   6.47 0.15  0.0   31  0.2  0.7         0
#  1571 2016-10-18 21:58       42 53   13 15   3.38 0.16  0.0   26  0.3  0.8         0
#  1572 2016-10-18 21:58       42 57   13 16   2.96 0.16  0.0   17  0.4  0.9         0
#  1573 2016-10-18 21:59       42 55   13 17   3.73 0.09  0.0   13  0.3  0.8         0
#  1574 2016-10-18 21:59       42 42   13 13   7.48 0.12  0.0   12  0.4  0.9         0
#  1575 2016-10-18 21:59       42 36   13 20   4.79 0.10  0.0   12  0.6  0.7         0
#   SEQ ---DATE--- TIME REMARK -LAT-  --LON-  DEPTH  RMS PMAG  NUM  ERH  ERZ  ID
#  1576 2016-10-18 22:03       42 38   13  6  10.73 0.04  0.0   12  0.3  0.5         0
#  1577 2016-10-18 22:03     # 42 46   13  8   0.21 0.20  0.0   12  0.5  0.9         0
#  1578 2016-10-18 22:04       42 49   13  5   6.23 0.14  0.0   10  0.4  1.0         0
#  1579 2016-10-18 22:05       42 47   13 14   1.26 0.11  0.0    8  0.6  1.7         0
#  1580 2016-10-18 22:06     # 42 46   13  9   0.22 0.15  0.0   16  0.3  0.6         0
#  1581 2016-10-18 22:06     # 42 51   13 15   2.63 0.16  0.0   10  0.8  2.3         0
#  1582 2016-10-18 22:07       42 44   13 12   3.93 0.14  0.0   15  0.3  0.6         0
#  1583 2016-10-18 22:07       42 55   13 16   2.46 0.11  0.0    9  0.5  1.4         0
#  1584 2016-10-18 22:09       42 44   13 11   4.61 0.21  0.0   17  0.4  1.2         0
#  1585 2016-10-18 22:10       42 53   13 13   2.63 0.14  0.0   41  0.2  0.5         0
#  1586 2016-10-18 22:11       42 45   13 15   8.37 0.15  0.0   40  0.2  0.5         0
#  1587 2016-10-18 22:12       42 50   13 16   4.27 0.05  0.0    8  1.1  0.5         0
#  1588 2016-10-18 22:15       42 39   13 20   4.54 0.09  0.0   11  0.5  2.8         0
#  1589 2016-10-18 22:15       42 45   13 10   3.52 0.30  0.0   16  0.8  1.3         0
#  1590 2016-10-18 22:16       42 48   13  5   6.68 0.14  0.0   44  0.2  0.6         0
#   SEQ ---DATE--- TIME REMARK -LAT-  --LON-  DEPTH  RMS PMAG  NUM  ERH  ERZ  ID
#  1591 2016-10-18 22:16       42 53   13 15   4.08 0.14  0.0   18  0.3  1.3         0
#  1592 2016-10-18 22:17       42 51   13 14   5.05 0.14  0.0   22  0.3  1.0         0
#  1593 2016-10-18 22:18       42 39   13 20   5.43 0.14  0.0   30  0.2  0.7         0
#  1594 2016-10-18 22:18     # 42 43   13 11   6.44 0.17  0.0    9  0.7  1.7         0
#  1595 2016-10-18 22:19       42 50   13 17   1.27 0.06  0.0   11  0.3  0.3         0
#  1596 2016-10-18 22:19       42 49   13 11   3.71 0.18  0.0   30  0.2  0.5         0
#  1597 2016-10-18 22:20       42 54   13 14   2.90 0.38  0.0   26  0.5  1.5         0
#  1598 2016-10-18 22:21       42 44   13 12   3.32 0.12  0.0   14  0.3  1.3         0
#  1599 2016-10-18 22:22       42 45   13 10   1.20 0.15  0.0   13  0.4  0.9         0
#  1600 2016-10-18 22:24       42 42   13 11   8.69 0.22  0.0   19  0.4  1.0         0
#  1601 2016-10-18 22:24       42 56   13 15   3.22 0.15  0.0   36  0.2  0.7         0
#  1602 2016-10-18 22:25       42 46   13 11   2.44 0.14  0.0   17  0.3  0.9         0
#  1603 2016-10-18 22:26       42 51   13 13   2.57 0.22  0.0   25  0.3  1.1         0
#  1604 2016-10-18 22:27       42 56   13 15   2.31 0.13  0.0   12  0.4  1.8         0
#  1605 2016-10-18 22:27       42 46   13 11   3.75 0.18  0.0   17  0.6  0.5         0
#   SEQ ---DATE--- TIME REMARK -LAT-  --LON-  DEPTH  RMS PMAG  NUM  ERH  ERZ  ID
#  1606 2016-10-18 22:28       42 52   13 14   4.71 0.14  0.0   18  0.3  1.8         0
#  1607 2016-10-18 22:28       42 38   13 18   7.15 0.14  0.0   13  0.5  0.9         0
#  1608 2016-10-18 22:29       42 52   13 12   2.53 0.17  0.0   20  0.3  1.1         0
#  1609 2016-10-18 22:29       42 43   13 13   9.76 0.14  0.0   42  0.2  0.5         0
#  1610 2016-10-18 22:30       42 54   13 15   3.91 0.14  0.0   25  0.2  0.5         0
#  1611 2016-10-18 22:30     # 42 56   13 12   1.85 0.09  0.0   10  0.7  1.6         0
#  1612 2016-10-18 22:32       42 40   13 13   7.70 0.19  0.0   21  0.4  0.7         0
#  1613 2016-10-18 22:32       42 45   13 11   1.80 0.12  0.0   10  0.4  0.9         0
#  1614 2016-10-18 22:32       42 47   13 11   6.14 0.03  0.0   10  0.5  0.6         0
#  1615 2016-10-18 22:33       42 41   13 12   8.82 0.14  0.0   23  0.3  0.6         0
#  1616 2016-10-18 22:35       42 39   13 16   8.43 0.09  0.0   10  0.4  0.8         0
#  1617 2016-10-18 22:35       42 53   13 14   4.81 0.12  0.0   16  0.3  1.3         0
#  1618 2016-10-18 22:36       42 51   13 16   0.78 0.09  0.0   12  0.3  0.9         0
#  1619 2016-10-18 22:37       42 47   13 12   3.77 0.11  0.0   16  0.2  0.5         0
#  1620 2016-10-18 22:39       42 53   13 14   3.96 0.16  0.0   19  0.2  0.5         0
#   SEQ ---DATE--- TIME REMARK -LAT-  --LON-  DEPTH  RMS PMAG  NUM  ERH  ERZ  ID
#  1621 2016-10-18 22:40       42 55   13 12   4.11 0.16  0.0   15  0.6  1.3         0
#  1622 2016-10-18 22:41       42 47   13 15   3.31 0.19  0.0   24  0.3  0.6         0
#  1623 2016-10-18 22:41     # 42 43   13 11   0.04 0.39  0.0   11  0.8  2.1         0
#  1624 2016-10-18 22:43       42 48   13  5   2.07 0.11  0.0   11  0.3  1.0         0
#  1625 2016-10-18 22:44       42 53   13 14   4.07 0.15  0.0   19  0.3  1.4         0
#  1626 2016-10-18 22:44       42 50   13 10   6.62 0.14  0.0   15  0.3  0.9         0
#  1627 2016-10-18 22:45       42 50   13  3   2.91 0.14  0.0   34  0.3  0.6         0
#  1628 2016-10-18 22:46       42 42   13 14   5.64 0.09  0.0   11  0.3  0.9         0
#  1629 2016-10-18 22:46       42 49   13 10   8.42 0.11  0.0   20  0.2  0.8         0
#  1630 2016-10-18 22:47       42 51   13 15   4.22 0.17  0.0   10  0.5  1.0         0
#  1631 2016-10-18 22:47       42 49   13 11   4.15 0.12  0.0   35  0.2  1.2         0
#  1632 2016-10-18 22:48       42 46   13 10   3.55 0.14  0.0   28  0.2  0.4         0
#  1633 2016-10-18 22:49       42 42   13 11   7.92 0.06  0.0    9  0.5  0.6         0
#  1634 2016-10-18 22:49       42 48   13 13   6.47 0.17  0.0   19  0.4  1.1         0
#  1635 2016-10-18 22:49       42 47   13 15   8.48 0.14  0.0   26  0.3  0.5         0
#   SEQ ---DATE--- TIME REMARK -LAT-  --LON-  DEPTH  RMS PMAG  NUM  ERH  ERZ  ID
#  1636 2016-10-18 22:51     # 42 49   13 11   4.02 0.12  0.0   22  0.2  1.4         0
#  1637 2016-10-18 22:52       42 53   13 14   3.82 0.15  0.0   20  0.3  0.6         0
#  1638 2016-10-18 22:52       42 48   13 10   3.09 0.13  0.0   21  0.3  0.7         0
#  1639 2016-10-18 22:53       42 52   13 14   3.42 0.19  0.0   18  0.3  1.1         0
#  1640 2016-10-18 22:53       42 50   13  9   7.59 0.15  0.0   28  0.2  0.6         0
#  1641 2016-10-18 22:54     # 42 51   13 11   3.89 0.68  0.0   15  1.7  2.5         0
#  1642 2016-10-18 22:55     # 42 43   13 15   0.63 0.23  0.0    6  2.2  9.1         0
#  1643 2016-10-18 22:55       42 43   13 11   6.16 0.20  0.0    9  0.8  1.5         0
#  1644 2016-10-18 22:56       42 45   13 11   4.32 0.14  0.0   32  0.2  0.9         0
#  1645 2016-10-18 22:58       42 45   13 12   3.17 0.12  0.0   34  0.2  0.5         0
#  1646 2016-10-18 23:00       42 45   13 15   9.51 0.17  0.0   12  0.5  1.1         0
#  1647 2016-10-18 23:01       42 39   13 15   9.60 0.16  0.0   29  0.3  0.6         0
#  1648 2016-10-18 23:01       42 45   13 11   5.23 0.13  0.0   33  0.2  0.8         0
#  1649 2016-10-18 23:03       42 53   13  9   1.79 0.15  0.0   30  0.3  0.6         0
#  1650 2016-10-18 23:06     # 42 53   13 14   1.97 0.13  0.0   10  0.3  0.8         0
#   SEQ ---DATE--- TIME REMARK -LAT-  --LON-  DEPTH  RMS PMAG  NUM  ERH  ERZ  ID
#  1651 2016-10-18 23:06     # 42 53   13 14   4.28 0.18  0.0   20  0.3  1.4         0
#  1652 2016-10-18 23:09       42 39   13 20   5.80 0.09  0.0   16  0.2  0.9         0
#  1653 2016-10-18 23:09     # 42 32   13 18   0.03 0.10  0.0   10  0.3  0.9         0
#  1654 2016-10-18 23:09       42 35   13 18   2.99 0.19  0.0   33  0.2  0.4         0
#  1655 2016-10-18 23:10       42 46   13 10   1.24 0.24  0.0   27  0.3  0.5         0
#  1656 2016-10-18 23:11     # 42 48   13 14   4.07 0.46  0.0   12  1.5  6.1         0
#  1657 2016-10-18 23:11       42 54   13 14   4.23 0.16  0.0   19  0.3  1.4         0
#  1658 2016-10-18 23:11       42 28   13 24   6.90 0.12  0.0   39  0.2  0.4         0
#  1659 2016-10-18 23:12       42 57   13 16   0.37 0.05  0.0    9  0.3  1.3         0
#  1660 2016-10-18 23:14       42 49   13 11   4.06 0.13  0.0   45  0.2  1.2         0
#  1661 2016-10-18 23:15       42 52   13 15   2.76 0.11  0.0    9  0.4  1.4         0
#  1662 2016-10-18 23:16     # 42 49   13 11   3.91 0.14  0.0   13  0.4  0.7         0
#  1663 2016-10-18 23:16       42 38   13 13   8.47 0.13  0.0   40  0.2  0.4         0
#  1664 2016-10-18 23:17     - 42 54   13 15   2.38 0.10  0.0    8  0.3  9.3         0
#  1665 2016-10-18 23:17       42 48   13  5   6.29 0.10  0.0   26  0.2  0.5         0
#   SEQ ---DATE--- TIME REMARK -LAT-  --LON-  DEPTH  RMS PMAG  NUM  ERH  ERZ  ID
#  1666 2016-10-18 23:18       42 52   13  7   0.72 0.06  0.0    7  0.6  1.2         0
#  1667 2016-10-18 23:18       42 45   13 15   6.84 0.10  0.0   20  0.2  0.5         0
#  1668 2016-10-18 23:19       42 36   13 15   5.62 0.51  0.0   11  2.2  2.9         0
#  1669 2016-10-18 23:20       42 50   13 12   3.93 0.15  0.0   30  0.2  0.6         0
#  1670 2016-10-18 23:21       42 49   13 14   2.20 0.15  0.0   17  0.3  2.0         0
#  1671 2016-10-18 23:21       42 52   13  6   3.30 0.17  0.0   12  0.5  1.2         0
#  1672 2016-10-18 23:21       42 39   13 20   5.87 0.10  0.0   12  0.4  1.2         0
#  1673 2016-10-18 23:22       42 55   13 16   3.52 0.19  0.0   40  0.3  0.8         0
#  1674 2016-10-18 23:23       42 51   13  9   4.27 0.09  0.0    8  1.2  3.1         0
#  1675 2016-10-18 23:24       42 54   13 14   4.65 0.16  0.0   17  0.4  1.6         0
#  1676 2016-10-18 23:25       42 55   13 16   4.15 0.15  0.0   20  0.3  1.4         0
#  1677 2016-10-18 23:26       42 48   13 19   7.14 0.09  0.0   11  0.4  1.4         0
#  1678 2016-10-18 23:27     # 42 49   13 12   2.63 0.10  0.0    7  0.9  2.0         0
#  1679 2016-10-18 23:28       42 51   13 10   4.44 0.17  0.0   22  0.3  1.4         0
#  1680 2016-10-18 23:29       42 47   13  9   6.36 0.05  0.0    7  0.4  0.9         0
#   SEQ ---DATE--- TIME REMARK -LAT-  --LON-  DEPTH  RMS PMAG  NUM  ERH  ERZ  ID
#  1681 2016-10-18 23:30       42 45   13 16   9.65 0.14  0.0   16  0.4  0.6         0
#  1682 2016-10-18 23:30       42 47   13  9   7.82 0.11  0.0   21  0.2  0.5         0
#  1683 2016-10-18 23:31       42 54   13 15   2.77 0.09  0.0   11  0.2  2.2         0
#  1684 2016-10-18 23:31       42 46   13 16   5.17 0.10  0.0   14  0.3  0.6         0
#  1685 2016-10-18 23:31       42 47   13 14   4.94 0.18  0.0    9  1.5  2.3         0
#  1686 2016-10-18 23:32       42 51   13 12   6.66 0.14  0.0   10  0.5  1.3         0
#  1687 2016-10-18 23:33       42 38   13 16   3.70 0.14  0.0   14  0.3  1.1         0
#  1688 2016-10-18 23:34       42 51   13  9   5.10 0.27  0.0   19  0.6  2.1         0
#  1689 2016-10-18 23:34       42 51   13 14   5.15 0.15  0.0   37  0.2  0.8         0
#  1690 2016-10-18 23:35       42 47   13  9   1.38 0.21  0.0   12  1.0  0.4         0
#  1691 2016-10-18 23:35       42 43   13 15   9.53 0.22  0.0   15  0.8  1.0         0
#  1692 2016-10-18 23:36       42 44   13 11   7.00 0.13  0.0   17  0.3  0.8         0
#  1693 2016-10-18 23:36       42 48   13  2   2.83 0.95  0.0   16  4.5  9.1         0
#  1694 2016-10-18 23:36       42 47   13 12   5.12 0.10  0.0   11  0.4  0.8         0
#  1695 2016-10-18 23:36       42 55   13 15   4.16 0.12  0.0   16  0.3  1.5         0
#   SEQ ---DATE--- TIME REMARK -LAT-  --LON-  DEPTH  RMS PMAG  NUM  ERH  ERZ  ID
#  1696 2016-10-18 23:37       42 45   13 18   8.84 0.05  0.0    8  0.7  0.5         0
#  1697 2016-10-18 23:38       42 47   13 14  14.40 0.32  0.0    9  1.4  1.5         0
#  1698 2016-10-18 23:38     - 42 54   13 15   2.00 0.13  0.0   11  0.4 13.9         0
#  1699 2016-10-18 23:39       42 47   13  8   1.00 0.16  0.0   32  0.2  0.2         0
#  1700 2016-10-18 23:39       42 41   13 17   6.58 0.08  0.0   11  0.7  1.3         0
#  1701 2016-10-18 23:40       42 47   13  7   7.57 0.17  0.0   21  0.4  0.6         0
#  1702 2016-10-18 23:40       42 52   13 14   2.90 0.14  0.0   10  0.4  1.2         0
#  1703 2016-10-18 23:42       42 53   13  9   1.58 0.08  0.0   16  0.4  0.7         0
#  1704 2016-10-18 23:42       42 49   13 11   3.92 0.13  0.0   36  0.2  0.5         0
#  1705 2016-10-18 23:43       42 52   13 14   4.63 0.14  0.0   15  0.3  1.1         0
#  1706 2016-10-18 23:45       42 35   13 17   3.75 0.11  0.0   15  0.3  0.5         0
#  1707 2016-10-18 23:45       42 47   13  8   5.92 0.09  0.0   16  0.3  0.4         0
#  1708 2016-10-18 23:49       42 49   13 14   1.41 0.10  0.0    8  0.6  1.2         0
#  1709 2016-10-18 23:50       42 44   13 10   1.41 0.07  0.0    9  0.2  0.9         0
#  1710 2016-10-18 23:50       42 51   13 12   5.69 0.19  0.0   23  0.3  1.1         0
#   SEQ ---DATE--- TIME REMARK -LAT-  --LON-  DEPTH  RMS PMAG  NUM  ERH  ERZ  ID
#  1711 2016-10-18 23:50       42 52   13 17   1.94 0.07  0.0    9  0.5  0.9         0
#  1712 2016-10-18 23:51       42 54   13 16   2.15 0.32  0.0   21  0.5  5.1         0
#  1713 2016-10-18 23:52       42 45   13 10   6.15 0.16  0.0   19  0.3  0.7         0
#  1714 2016-10-18 23:53       42 54   13 14   3.46 0.15  0.0   19  0.3  1.1         0
#  1715 2016-10-18 23:53       42 53   13 15   4.83 0.11  0.0   16  0.3  1.0         0
#  1716 2016-10-18 23:54       42 53   13 15   3.87 0.10  0.0    9  0.4  0.9         0
#  1717 2016-10-18 23:54       42 47   13  8   0.19 0.28  0.0   13  0.6  2.0         0
#  1718 2016-10-18 23:54       42 51   13  5   2.52 0.15  0.0   25  0.3  0.6         0
#  1719 2016-10-18 23:56       42 44   13 10   4.09 0.90  0.0   12  3.0  5.8         0
#  1720 2016-10-18 23:56       42 40   13 13   7.83 0.22  0.0   24  0.4  0.8         0
#  1721 2016-10-18 23:57       42 50   13  9   7.47 0.14  0.0   14  0.4  0.8         0
#  1722 2016-10-18 23:57       42 49   13 11   3.83 0.13  0.0   40  0.2  0.5         0
#  1723 2016-10-18 23:59     # 42 52   13 10   1.85 0.16  0.0   10  0.7  1.9         0
#  COMMAND?

# %% [markdown]
# ### Plot HypoInverse location results
# Load the HypoInvere Output file:

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import obspy
import pandas as pd
import numpy as np

events_hpy = pd.read_csv('./hypoInv/catOut.sum', names=[ "lines" ])

events_hpy['YRMODY']=events_hpy['lines'].apply(lambda x: x[0:8])
events_hpy['HR']=events_hpy['lines'].apply(lambda x: x[8:10])
events_hpy['MIN']=events_hpy['lines'].apply(lambda x: x[10:12])
events_hpy['SEC']=events_hpy['lines'].apply(lambda x: x[12:16])
events_hpy['LAT']=events_hpy['lines'].apply(lambda x: float(x[16:18])+float(x[19:23])/6000)
events_hpy['LON']=events_hpy['lines'].apply(lambda x: float(x[23:26])+float(x[27:31])/6000)
events_hpy['DEPTH']=events_hpy['lines'].apply(lambda x: float(x[33:36])/100)
events_hpy['RMS']=events_hpy['lines'].apply(lambda x: float(x[48:52])/100)

print(len(events_hpy))
# Out:
# 1723

# %% [markdown]
# ##### Plot event locations:

# %%
marker_size=5
hyp_label="HypoInv"
fig = plt.figure(figsize=plt.rcParams["figure.figsize"]*np.array([2,2]))
box = dict(boxstyle='round', facecolor='white', alpha=1)
text_loc = [0.05, 0.92]
grd = fig.add_gridspec(ncols=2, nrows=2, width_ratios=[1.5, 1], height_ratios=[1,1])
fig.add_subplot(grd[:, 0])
plt.plot(stations["longitude"], stations["latitude"], 'k^', markersize=1.5*marker_size, alpha=0.5, label="Stations")
plt.plot(events_hpy["LON"], events_hpy["LAT"], '.',markersize=marker_size, alpha=1.0, rasterized=True, label=f"{hyp_label}: {len(events_hpy)}")

plt.gca().set_aspect(111/82)
plt.xlim(np.array(config["xlim_degree"])+np.array([-0.03,0.03]))
plt.ylim(np.array(config["ylim_degree"])+np.array([-0.03,0.03]))
plt.ylabel("Latitude")
plt.xlabel("Longitude")
plt.gca().set_prop_cycle(None)
plt.plot(config["xlim_degree"][0]-10, config["ylim_degree"][0]-10, '.', markersize=10)
plt.legend(loc="lower right")
plt.text(text_loc[0], text_loc[1], '(i)', horizontalalignment='left', verticalalignment="top",
         transform=plt.gca().transAxes, fontsize="large", fontweight="normal", bbox=box)

fig.add_subplot(grd[0, 1])
plt.plot(events_hpy["LON"], events_hpy["DEPTH"], '.', markersize=marker_size, alpha=1.0, rasterized=True,label=f"{hyp_label}")

plt.xlim(np.array(config["xlim_degree"])+np.array([-0.03,0.03]))
plt.ylim(bottom=0, top=12)
plt.gca().invert_yaxis()
plt.xlabel("Longitude")
plt.ylabel("Depth (km)")
plt.gca().set_prop_cycle(None)
plt.plot(config["xlim_degree"][0]-10, 31, '.', markersize=10)
plt.legend(loc="lower right")
plt.text(text_loc[0], text_loc[1], '(ii)', horizontalalignment='left', verticalalignment="top",
         transform=plt.gca().transAxes, fontsize="large", fontweight="normal", bbox=box)


fig.add_subplot(grd[1, 1])
plt.plot(events_hpy["LAT"], events_hpy["DEPTH"], '.', markersize=marker_size, alpha=1.0, rasterized=True,label=f"{hyp_label}")

plt.xlim(np.array(config["ylim_degree"])+np.array([-0.03,0.03]))
plt.ylim(bottom=0, top=12)
plt.gca().invert_yaxis()
plt.xlabel("Latitude")
plt.ylabel("Depth (km)")
plt.gca().set_prop_cycle(None)
plt.plot(config["ylim_degree"][0]-10, 31, '.', markersize=10)
plt.legend(loc="lower left")
plt.tight_layout()
plt.text(text_loc[0], text_loc[1], '(iii)', horizontalalignment='left', verticalalignment="top",
         transform=plt.gca().transAxes, fontsize="large", fontweight="normal", bbox=box)

plt.show()

# %% [markdown]
# ##### Write HypoDD input phase file from HypoInverese output

# %%
import datetime
import math
import sys
import os

def format_convert(phaseinput,phaseoutput):

    g = open(phaseoutput, 'w')
    nn = 100000

    with open(phaseinput, "r") as f:
        for line in f:
            if (len(line) == 180):
                iok = 0
                RMS = float(line[48:52]) / 100
                gap = int(line[42:45])
                dep = float(line[31:36])/100
                EZ = float(line[89:93])/100
                EH = float(line[85:89])/100

                nn = nn + 1
                year = int(line[0:4])
                mon = int(line[4:6])
                day = int(line[6:8])
                hour = int(line[8:10])
                min = int(line[10:12])
                sec = int(line[12:16])/100

                if line[18] == ' ': #N
                    lat = (float(line[16:18]) + float(line[19:23]) / 6000)
                else:
                    lat = float(line[16:18]) + float(line[19:23])/6000 * (-1)

                if line[26] == 'E':
                    lon = (float(line[23:26]) + float(line[27:31]) / 6000)
                else:
                    lon = (float(line[23:26]) + float(line[27:31]) / 6000) * (-1)

                mag = float(line[123:126])/100
                g.write(
                    '# {:4d} {:2d} {:2d} {:2d} {:2d} {:5.2f}  {:7.4f} {:9.4f}   {:5.2f} {:5.2f} {:5.2f} {:5.2f} {:5.2f} {:9d} E\n'.format(
                        year, mon, day, hour, min, sec, lat, lon, dep, mag, EH, EZ, RMS, nn))
                iok = 1
            else:
                if (iok == 1 and len(line) == 121):
                    station = line[0:5]
                    net = line[5:7]
                    chn = line[9:11]
                    year1 = int(line[17:21])
                    mon1 = int(line[21:23])
                    day1 = int(line[23:25])
                    hour1 = int(line[25:27])
                    min1 = int(line[27:29])

                    if year1 == year and mon1 == mon and day1 == day and hour1 == hour and min1 == min:
                        sec_p =sec
                        if line[13:15] == ' P' or line[13:15] == 'IP':
                            P_residual = abs(int(line[34:38]) / 100)
                            sec_p = int(line[29:34]) / 100
                            ppick = sec_p-sec
                            
                            g.write('{:<2s}{:<5s}    {:8.3f}   1.000   P {:<2s} \n'.format(net, station, ppick,chn))

                        if line[46:48] == ' S' or line[46:48] == 'ES':
                            S_residual = abs(int(line[50:54]) / 100)
                            sec_s = int(line[41:46]) / 100
                            spick = sec_s-sec
                            
                            g.write('{:<2s}{:<5s}    {:8.3f}   1.000   S {:<2s} \n'.format(net, station, spick,chn))
    f.close()
    g.close()

# %cd /app
input_file = './hypoInv/hypoOut.arc'
Path('./hypodd/results_hypodd').mkdir(parents=True, exist_ok=True)
output_file = './hypodd/results_hypodd/hypoDD.pha'
format_convert(input_file, output_file)
print('phase file:', output_file)
# %cp stations_hypoDD.dat ./hypodd/results_hypodd/.
# Out:
# /app
# phase file: ./hypodd/results_hypodd/hypoDD.pha

# %% [markdown]
# ### Run XTime: Calculate delay times using cross-correlation
#
# See more details in
#
# - Schaff, David P., et al. "Optimizing correlation techniques for improved earthquake location." Bulletin of the Seismological Society of America 94.2 (2004): 705-721.

# %% [markdown]
# ##### Cut event wavefroms for correlation calculation based on the phase picks

# %%
events_pha = pd.read_csv('/app/hypodd/results_hypodd/hypoDD.pha', sep="\t", names=[ "lines" ])

line_idx=np.where(events_pha['lines'].apply(lambda x: x[0]=='#'))
Origintime=events_pha.iloc[line_idx]['lines'].apply(lambda x: UTCDateTime(int(x[2:6]),int(x[7:9]),int(x[10:12]),int(x[13:15]),int(x[16:18]),float(x[19:24])))
EventId=events_pha.iloc[line_idx]['lines'].apply(lambda x: x[-8:-2])

def cutwaves(Net, Sta):
    os.makedirs('/app/cc/cuts/'+Net+'.'+Sta, exist_ok=True)
    wavelist=glob.glob('/app/waveforms/'+Net+'/'+Sta+'/*.mseed')
    channel_list=np.unique([i.split('/')[-1][0:3] for i in wavelist])

    for Cha in channel_list:
        st=obspy.read('/app/waveforms/'+Net+'/'+Sta+'/'+Cha+'.*.mseed')
        st=st.sort()
        st=st.merge(fill_value=0)
        for i in range(len(Origintime)):
            try:
                evmseed=st.slice(Origintime.iloc[i]-10,Origintime.iloc[i]+50)
                if len(evmseed)>0:
                    evmseed.write('/app/cc/cuts/'+Net+'.'+Sta+'/'+EventId.iloc[i]+'.'+Net+'.'+Sta+'.'+evmseed[0].stats.channel, format='MSEED')
            except:
                print('error cut '+EventId.iloc[i])

# %%
import multiprocessing as mp
import time

pool = mp.Pool(mp.cpu_count())
for Net in ['YR']:
    stalist=glob.glob('/app/waveforms/'+Net+'/*')
    stanames=[stapath.split('/')[-1] for stapath in stalist]
    for Sta in stanames:
        pool.apply_async(cutwaves,args=(Net, Sta))
        while pool._taskqueue.qsize() > 200:
            time.sleep(1)
pool.close()
pool.join()

# %% [markdown]
# ##### Run correlation delay time measurements

# %%
# %cp /app/hypodd/results_hypodd/hypoDD.pha /app/cc/amatrice/pha.dat
# get_ipython().system = os.system

os.system("""
cd /app/cc/amatrice
./getmseedfiles
./getcat
""")
# Out:
# YR.ED01
# YR.ED02
# YR.ED03
# YR.ED04
# YR.ED05
# YR.ED06
# YR.ED07
# YR.ED08
# YR.ED09
# YR.ED10
# YR.ED11
# YR.ED12
# YR.ED14
# YR.ED15
# YR.ED16
# YR.ED17
# YR.ED18
# YR.ED19
# YR.ED20
# YR.ED21
# YR.ED22
# YR.ED23
# YR.ED24
# YR.ED25
# 0

# %%
import subprocess

command_1_1 = "cd /app/cc/amatrice/preprocess/runs \n ./runpreprocess.chasZ &> outZ &"
p1_1 = subprocess.Popen(command_1_1, stdout=subprocess.PIPE, shell=True)

(output1_1, err1_1) = p1_1.communicate()  
p_status_1_1 = p1_1.wait()

command_1_2 = "cd /app/cc/amatrice/preprocess/runs \n ./runpreprocess.chasH &> outH &"
p1_2 = subprocess.Popen(command_1_2, stdout=subprocess.PIPE, shell=True)

(output1_2, err1_2) = p1_2.communicate()  
p_status_1_2 = p1_2.wait()


command_2_1 = "cd /app/cc/amatrice/correl/runs \n ./runcorrel9.chasZ &> outZ &"
p2_1 = subprocess.Popen(command_2_1, stdout=subprocess.PIPE, shell=True)

(output2_1, err2_1) = p2_1.communicate()  
p_status_2_1 = p2_1.wait()

command_2_2 = "cd /app/cc/amatrice/correl/runs \n ./runcorrel9.chasN &> outN &"
p2_2 = subprocess.Popen(command_2_2, stdout=subprocess.PIPE, shell=True)

(output2_2, err2_2) = p2_2.communicate()  
p_status_2_2 = p2_2.wait()

command_2_3 = "cd /app/cc/amatrice/correl/runs \n ./runcorrel9.chasE &> outE &"
p2_3 = subprocess.Popen(command_2_3, stdout=subprocess.PIPE, shell=True)

(output2_3, err2_3) = p2_3.communicate()  
p_status_2_3 = p2_3.wait()


command_3 = "cd /app/cc/amatrice/correl/runs \n ./runselect5 &> select.out &"
p3 = subprocess.Popen(command_3, stdout=subprocess.PIPE, shell=True)

(output3, err3) = p3.communicate()  
p_status_3 = p3.wait()
# Out:
# mkdir: cannot create directory ‘/app/cc/amatrice/corr’: File exists
# mkdir: cannot create directory ‘/app/cc/amatrice/corr’: File exists
# mkdir: cannot create directory ‘/app/cc/amatrice/corr/corr.Swaves’: File exists

# %% [markdown]
# ##### Convert Correl outputs into HypoDD dt.cc format
#
# Convert original station based XTime output to event-pair based hypoDD input format
#
# run:
# ```./convcc.sh dir pha.all.cc pha.all nP ```
#
# dir: 		directory with original correl output files
#
# Format:
# - Filename: NET.STA.cc.COMP.PHA (e.g. IV.SSFR.cc.HNE.S)
# - Content: lines of ID1 ID2 DT CC
#
#  pha.all.cc: 	phase file used for cc delay time measurements
#
#  pha.all: 	phase file to be comobined with cc measurements
#
#  nP: 		# of min P-wave delay times required to retain link
# 		between event pair
#
# note: if same phase file is used for cc measurements and pick delay times, then
#
# run:
# ```./convcc.sh dir - - nP ```

# %%
# %cd /app/cc/convcc
# !mkdir select
# !cp /app/cc/amatrice/pha.dat pha.all.cc
# !cp /app/hypodd/results_hypodd/hypoDD.pha pha.all
# !cp /app/cc/amatrice/corr/corr.Pwaves/select/*.P /app/cc/convcc/select/.
# !cp /app/cc/amatrice/corr/corr.Swaves/select/*.S /app/cc/convcc/select/.
# !./convcc.sh ./select pha.all pha.all 3 
# !cp /app/cc/convcc/dt.cc.P5 /app/hypodd/results_hypodd/dt.cc
# Out:
# /app/cc/convcc
# convert cc to dt.cc...
# rm: cannot remove 'ccP': No such file or directory
# rm: cannot remove 'ccS': No such file or directory
#  Input file = dtcc
#  Output file = dt.cc.0.all
#  Done.
# no OT correction.
# sort: cannot read: NoPhaEv.dat: No such file or directory
# 0
#   Total events in catalog =        19567

# %% [markdown]
# ### Run HypoDD
# Run with test data of one-day picks.
#
# The following code blocks convert the output from HypoInvese into HypoDD input format.
#
# When running HypoDD, you may need to change the .inp files.
#
# See HypoDD manual (https://github.com/fwaldhauser/HypoDD)

# %% [markdown]
# ##### Convert phase file to time difference file (dt.ct)

# %%
# %cd /app/hypodd/results_hypodd
# %pwd
# !ph2dt ph2dt.inp
# Out:
# /app/hypodd/results_hypodd
# starting ph2dt (v2.1b - 08/2012)...     Thu May 23 14:40:46 2024
#
# reading data ...
#  > stations =           24
#  > events total =         1723
#  > events selected =         1723
#  > phases =        36160
# forming dtimes...
#  > stations selected =           24
#  > P-phase pairs total =       386624
#  > S-phase pairs total =       405801
#  > outliers =        42098  (           5 %)
#  > phases at stations not in station list =            0
#  > phases at distances larger than MAXDIST =            0
#  > P-phase pairs selected =       336450  (          87 %)
#  > S-phase pairs selected =       365921  (          90 %)
#  > weakly linked events =           62  (           3 %)
#  > linked event pairs =        47594
#  > average links per pair =           14
#  > average offset (km) betw. linked events =    2.75218892
#  > average offset (km) betw. strongly linked events =    2.88173079
#  > maximum offset (km) betw. strongly linked events =    11.9996042
#
# Done.  Thu May 23 14:40:49 2024
#
# Output files: dt.ct; event.dat; event.sel; station.sel; ph2dt.log
# ph2dt parameters were:
# (minwght,maxdist,maxsep,maxngh,minlnk,minobs,maxobs)
#  0.01  150.000   12.000  50   5   8  60

# %% [markdown]
# ##### Run double-difference relocation

# %%
# !hypoDD hypoDD.inp
# Out:
# starting hypoDD (v2.1beta - 06/15/2016)...   Thu May 23 14:40:49 2024
# Input parameters: hypoDD.inp (hypoDD2.0 format)
# INPUT FILES:
#  cross dtime data: dt.cc
#  catalog dtime data: dt.ct
#  events: event.sel
#  stations: station.sel
# OUTPUT FILES:
#  initial locations: hypoDD.loc
#  relocated events: hypoDD.reloc
#  event pair residuals: hypoDD.res
#  station residuals: hypoDD.sta
#  source parameters: hypoDD.src
# Use local layered 1D model.
# Relocate cluster number    1
# Relocate all events
# Remove air quakes.
# Reading data ...   Thu May 23 14:40:49 2024
# # events =  1723
# # stations < maxdist =     24
# # stations w/ neg. elevation (set to 0) =    0
# # cross corr P dtimes =   12218 (no OTC for      0 event pairs)
# # cross corr S dtimes =   21396 (no OTC for      0 event pairs)
# # catalog P dtimes =  332402
# # catalog S dtimes =  361599
# # dtimes total =   727615
# # events after dtime match =       1692
# # stations =     24
# clustering ...
# Clustered events:  1692
# Isolated events:     0
# # clusters:    4
# Cluster   1:  1680 events
# Cluster   2:     8 events
# Cluster   3:     2 events
# Cluster   4:     2 events
#
# RELOCATION OF CLUSTER: 1     Thu May 23 14:40:51 2024
# ----------------------
# Reading data ...   Thu May 23 14:40:51 2024�
# # events =  1680
# # stations < maxdist =     24
# # stations w/ neg. elevation (set to 0) =    0
# # cross corr P dtimes =   12199 (no OTC for      0 event pairs)
# # cross corr S dtimes =   21341 (no OTC for      0 event pairs)
# # catalog P dtimes =  332248
# # catalog S dtimes =  361396
# # dtimes total =   727184
# # events after dtime match =       1680
# # stations =     24
# Initial trial sources =  1680
# 1D ray tracing.
#
#   IT   EV  CT  CC    RMSCT      RMSCC   RMSST   DX   DY   DZ   DT   OS  AQ  CND
#         %   %   %   ms     %   ms     %    ms    m    m    m   ms    m
#  1    100 100 100  193 -22.5  140 -12.3     0  472  396  920   66    0  89   87
#  2     95  94  99  187  -2.8  136  -3.3     0  454  376  831   63    0   2   84
#  3  1  94  94  99  185  -1.2  135  -0.3   421  451  373  825   62  366   0   84
#  4     94  93  99  137 -25.9  119 -11.8   421  150  144  363   26  366  21   89
#  5     93  92  98  135  -1.6  118  -1.1   421  149  142  346   25  366   2   89
#  6  2  93  91  98  134  -0.5  118  -0.1   367  150  142  344   25  414   0   89
#  7     93  90  98  122  -9.3  113  -4.5   367   84   83  225   16  414   7   87
#  8  3  92  90  98  121  -0.9  112  -0.4   334   83   82  216   15  443   0   87
#  9     92  90  98  115  -4.9  110  -2.0   334   55   56  153   10  443   4   83
# 10  4  92  89  98  114  -0.5  110  -0.1   320   54   56  148   10  487   0   85
# 11     92  89  98  111  -2.8  108  -1.3   320   42   43  121    8  487  12   83
# 12  5  91  88  98  110  -0.5  108  -0.6   313   41   42  112    7  502   0   83
# 13     91  87  97  102  -7.1   74 -31.0   313   35   37  112    6  502   1   80
# 14  6  91  87  97  102  -0.8   74  -1.0   273   36   38  112    6  536   0   80
# 15     91  86  96   99  -2.6   74   0.8   273   27   27   95    5  536   5   81
# 16  7  90  86  96   99  -0.2   71  -3.7   264   27   27   80    5  531   0   81
# 17     90  86  96   97  -1.5   70  -1.9   264   22   20   75    4  531   4   76
# 18  8  90  85  96   97  -0.2   70  -0.3   260   22   20   73    4  570   0   76
# 19     90  85  96   96  -0.9   69  -0.5   260   20   17   63    3  570   1   76
# 20  9  90  85  96   96  -0.2   69  -0.1   258   20   18   63    3  560   0   76
# 21     90  85  96   95  -0.8   69  -0.2   258   17   14   60    3  560   3   74
# 22 10  90  85  96   95  -0.2   69  -0.0   256   17   14   59    3  576   0   74
# 23     89  81  95   77 -18.6   54 -22.1   256   28   32   75    5  576   1   76
# 24 11  89  81  95   75  -2.2   53  -1.2   189   30   34   77    5  543   0   76
# 25     89  80  93   72  -5.1   45 -15.5   189   19   22   57    4  543   2   72
# 26 12  89  80  93   71  -0.7   45  -1.3   177   19   22   57    4  560   0   72
# 27     89  80  93   69  -2.8   42  -6.3   177   14   15   63    3  560   2   72
# 28 13  89  79  93   69  -0.4   42  -0.5   170   14   16   47    3  558   0   72
# 29     89  79  92   68  -1.6   40  -3.5   170   11   12   41    2  558   1   72
# 30 14  89  79  92   68  -0.3   40  -0.3   167   11   12   40    2  568   0   72
# 31 15  89  79  92   67  -0.9   39  -1.3   165    9    9   36    2  570   0   70
# 32     89  79  90   70   4.1   18 -53.8   165   27   32   78    7  570   2   78
# 33 16  89  78  89   69  -0.4   18  -2.8   163   27   31   76    7  576   0   78
# 34 17  89  78  83   68  -2.0    8 -56.3   161   11   12   39    2  580   0   74
# 35     89  78  81   67  -0.9    6 -22.5   161    8    8   28    2  580   1   71
# 36 18  89  78  80   67  -0.1    6  -1.7   160    8    9   28    2  583   0   74
# 37     89  78  79   67  -0.7    5  -7.0   160    7    7   24    1  583   1   72
# 38     89  78  79   67  -0.1    5  -0.8   160    7    7   25    1  583   1   72
# 39 19  89  78  79   67  -0.0    5  -0.1   160    7    7   24    1  585   0   72
# 40 20  89  78  78   67  -0.3    5  -3.4   159    5    5   21    1  582   0   70
# 41     89  77  76   67   0.7    4 -28.1   159    9    9   26    2  582   1  105
# 42 21  89  77  76   67  -0.3    4  -1.7   157    9    9   26    2  577   0  105
# 43     89  77  74   67   0.4    3 -16.8   157    5    5   18    1  577   1  100
# 44 22  88  77  74   67  -0.1    3  -1.8   157    5    5   18    1  571   0  100
# 45 23  88  77  73   67   0.2    3  -6.4   157    4    4   14    1  572   0   97
# 46 24  88  77  73   67   0.1    3  -4.6   157    3    3   13    1  572   0   96
# 47 25  88  77  72   67   0.1    3  -2.7   157    3    2   12    0  572   0   94
#
# writing out results ...
#    Program hypoDD finished. Thu May 23 14:42:27 2024

# %% [markdown]
# ##### Read HypoDD output

# %%
events_hypodd = pd.read_csv('./hypoDD.reloc',header=None, sep="\s+",names=['ID', 'LAT', 'LON', 'DEPTH', 'X', 'Y', 'Z', 'EX', 'EY', 'EZ', 'YR', 'MO', 'DY', 'HR', 'MI', 'SC', 'MAG', 'NCCP', 'NCCS', 'NCTP', 'NCTS', 'RCC', 'RCT', 'CID'])
events_hypodd
# Out:
#           ID        LAT        LON   DEPTH       X        Y       Z   EX   EY  \
# 0     100001  42.748905  13.192384   3.996 -1095.5  -3399.2   229.8  1.2  1.7
# 1     100002  42.835718  13.162125   5.436 -3569.8   6244.7  1670.7  0.4  0.5
# 2     100003  42.633940  13.194825  10.456  -896.5 -16170.6  6690.4  1.1  1.0
# 3     100004  42.764754  13.186208   4.838 -1600.8  -1638.6  1072.2  0.3  0.8
# 4     100005  42.755371  13.179279   2.393 -2168.1  -2680.9 -1373.0  0.4  0.4
# ...      ...        ...        ...     ...     ...      ...     ...  ...  ...
# 1481  101719  42.713717  13.182287   7.780 -1922.5  -7308.3  4014.3  0.4  0.9
# 1482  101720  42.660368  13.217240   7.239   939.7 -13234.7  3473.5  0.5  0.4
# 1483  101721  42.824967  13.137745   9.519 -5564.4   5050.4  5753.2  0.1  0.2
# 1484  101722  42.817558  13.182197   2.283 -1928.3   4227.3 -1483.3  0.3  0.2
# 1485  101723  42.869674  13.174165   0.511 -2584.3  10016.8 -3254.6  1.1  0.6
#
#        EZ  ...  MI     SC  MAG  NCCP  NCCS  NCTP  NCTS    RCC    RCT  CID
# 0     3.2  ...   0  55.46  0.0     0     0   231   290 -9.000  0.114    1
# 1     0.7  ...   1  43.74  0.0     4     0   764   806  0.000  0.107    1
# 2     1.5  ...   2   9.05  0.0     0     0   107    16 -9.000  0.130    1
# 3     0.5  ...   2  34.82  0.0     0     3   507   364  0.001  0.096    1
# 4     0.7  ...   2  41.50  0.0    11    47   597   566  0.004  0.100    1
# ...   ...  ...  ..    ...  ...   ...   ...   ...   ...    ...    ...  ...
# 1481  0.8  ...  56   1.96  0.0     0     0   201    92 -9.000  0.092    1
# 1482  0.5  ...  56   6.44  0.0    17    20   614   659  0.004  0.069    1
# 1483  0.3  ...  57  15.18  0.0     7    22   240   264  0.002  0.100    1
# 1484  0.5  ...  57  33.36  0.0    78   200   552   590  0.006  0.120    1
# 1485  1.7  ...  59  12.56  0.0     0     0   165   171 -9.000  0.076    1
#
# [1486 rows x 24 columns]

# %% [markdown]
# ##### Plot event locations

# %%
marker_size=5
hyp_label="HypoInv"
hypodd_label='HypoDD'
fig = plt.figure(figsize=plt.rcParams["figure.figsize"]*np.array([2,2]))
box = dict(boxstyle='round', facecolor='white', alpha=1)
text_loc = [0.05, 0.92]
grd = fig.add_gridspec(ncols=2, nrows=2, width_ratios=[1.5, 1], height_ratios=[1,1])
fig.add_subplot(grd[:, 0])
plt.plot(stations["longitude"], stations["latitude"], 'k^', markersize=1.5*marker_size, alpha=0.5, label="Stations")
plt.plot(events_hpy["LON"], events_hpy["LAT"], '.',markersize=marker_size, alpha=1.0, rasterized=True, label=f"{hyp_label}: {len(events_hpy)}")
plt.plot(events_hypodd["LON"], events_hypodd["LAT"], '.',markersize=marker_size, alpha=1.0, rasterized=True, label=f"{hypodd_label}: {len(events_hypodd)}")


plt.gca().set_aspect(111/82)
plt.xlim(np.array(config["xlim_degree"])+np.array([-0.03,0.03]))
plt.ylim(np.array(config["ylim_degree"])+np.array([-0.03,0.03]))
plt.ylabel("Latitude")
plt.xlabel("Longitude")
plt.gca().set_prop_cycle(None)
plt.plot(config["xlim_degree"][0]-10, config["ylim_degree"][0]-10, '.', markersize=10)
plt.legend(loc="lower right")
plt.text(text_loc[0], text_loc[1], '(i)', horizontalalignment='left', verticalalignment="top",
         transform=plt.gca().transAxes, fontsize="large", fontweight="normal", bbox=box)

fig.add_subplot(grd[0, 1])
plt.plot(events_hpy["LON"], events_hpy["DEPTH"], '.', markersize=marker_size, alpha=1.0, rasterized=True,label=f"{hyp_label}")
plt.plot(events_hypodd["LON"], events_hypodd["DEPTH"], '.', markersize=marker_size, alpha=1.0, rasterized=True,label=f"{hypodd_label}")


plt.xlim(np.array(config["xlim_degree"])+np.array([-0.03,0.03]))
plt.ylim(bottom=0, top=12)
plt.gca().invert_yaxis()
plt.xlabel("Longitude")
plt.ylabel("Depth (km)")
plt.gca().set_prop_cycle(None)
plt.plot(config["xlim_degree"][0]-10, 31, '.', markersize=10)
plt.legend(loc="lower right")
plt.text(text_loc[0], text_loc[1], '(ii)', horizontalalignment='left', verticalalignment="top",
         transform=plt.gca().transAxes, fontsize="large", fontweight="normal", bbox=box)


fig.add_subplot(grd[1, 1])
plt.plot(events_hpy["LAT"], events_hpy["DEPTH"], '.', markersize=marker_size, alpha=1.0, rasterized=True,label=f"{hyp_label}")
plt.plot(events_hypodd["LAT"], events_hypodd["DEPTH"], '.', markersize=marker_size, alpha=1.0, rasterized=True,label=f"{hypodd_label}")

plt.xlim(np.array(config["ylim_degree"])+np.array([-0.03,0.03]))
plt.ylim(bottom=0, top=12)
plt.gca().invert_yaxis()
plt.xlabel("Latitude")
plt.ylabel("Depth (km)")
plt.gca().set_prop_cycle(None)
plt.plot(config["ylim_degree"][0]-10, 31, '.', markersize=10)
plt.legend(loc="lower left")
plt.tight_layout()
plt.text(text_loc[0], text_loc[1], '(iii)', horizontalalignment='left', verticalalignment="top",
         transform=plt.gca().transAxes, fontsize="large", fontweight="normal", bbox=box)

plt.show()
